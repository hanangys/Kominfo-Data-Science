# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import nltk
from collections import OrderedDict
from nltk.stem import WordNetLemmatizer 
from sklearn.preprocessing import OneHotEncoder
from nltk.corpus import stopwords
from scipy.sparse import hstack,csr_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import CountVectorizer
import re
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from tqdm import tqdm
sns.set()

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
# Hit Enter to continue:
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] crubadan............ Crubadan Corpus
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] dolch............... Dolch Word List
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] framenet_v17........ FrameNet 1.7
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
#   [ ] large_grammars...... Large context-free and feature-based grammars
#                            for parser comparison
# Hit Enter to continue:
#   [ ] lin_thesaurus....... Lin's Dependency Thesaurus
#   [ ] mac_morpho.......... MAC-MORPHO: Brazilian Portuguese news text with
#                            part-of-speech tags
#   [ ] machado............. Machado de Assis -- Obra Completa
#   [ ] masc_tagged......... MASC Tagged Corpus
#   [ ] maxent_ne_chunker... ACE Named Entity Chunker (Maximum entropy)
#   [ ] maxent_treebank_pos_tagger Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] moses_sample........ Moses Sample Models
#   [ ] movie_reviews....... Sentiment Polarity Dataset Version 2.0
#   [ ] mte_teip5........... MULTEXT-East 1984 annotated corpus 4.0
#   [ ] mwa_ppdb............ The monolingual word aligner (Sultan et al.
#                            2015) subset of the Paraphrase Database.
#   [ ] names............... Names Corpus, Version 1.3 (1994-03-29)
#   [ ] nombank.1.0......... NomBank Corpus 1.0
#   [ ] nonbreaking_prefixes Non-Breaking Prefixes (Moses Decoder)
#   [ ] nps_chat............ NPS Chat
#   [ ] omw................. Open Multilingual Wordnet
#   [ ] opinion_lexicon..... Opinion Lexicon
#   [ ] panlex_swadesh...... PanLex Swadesh Corpora
#   [ ] paradigms........... Paradigm Corpus
#   [ ] pe08................ Cross-Framework and Cross-Domain Parser
#                            Evaluation Shared Task
# Hit Enter to continue:
#   [ ] perluniprops........ perluniprops: Index of Unicode Version 7.0.0
#                            character properties in Perl
#   [ ] pil................. The Patient Information Leaflet (PIL) Corpus
#   [ ] pl196x.............. Polish language of the XX century sixties
#   [ ] porter_test......... Porter Stemmer Test Files
#   [ ] ppattach............ Prepositional Phrase Attachment Corpus
#   [ ] problem_reports..... Problem Report Corpus
#   [ ] product_reviews_1... Product Reviews (5 Products)
#   [ ] product_reviews_2... Product Reviews (9 Products)
#   [ ] propbank............ Proposition Bank Corpus 1.0
#   [ ] pros_cons........... Pros and Cons
#   [ ] ptb................. Penn Treebank
#   [ ] punkt............... Punkt Tokenizer Models
#   [ ] qc.................. Experimental Data for Question Classification
#   [ ] reuters............. The Reuters-21578 benchmark corpus, ApteMod
#                            version
#   [ ] rslp................ RSLP Stemmer (Removedor de Sufixos da Lingua
#                            Portuguesa)
#   [ ] rte................. PASCAL RTE Challenges 1, 2, and 3
#   [ ] sample_grammars..... Sample Grammars
#   [ ] semcor.............. SemCor 3.0
# Hit Enter to continue:
#   [ ] senseval............ SENSEVAL 2 Corpus: Sense Tagged Text
#   [ ] sentence_polarity... Sentence Polarity Dataset v1.0
#   [ ] sentiwordnet........ SentiWordNet
#   [ ] shakespeare......... Shakespeare XML Corpus Sample
#   [ ] sinica_treebank..... Sinica Treebank Corpus Sample
#   [ ] smultron............ SMULTRON Corpus Sample
#   [ ] snowball_data....... Snowball Data
#   [ ] spanish_grammars.... Grammars for Spanish
#   [ ] state_union......... C-Span State of the Union Address Corpus
#   [ ] stopwords........... Stopwords Corpus
#   [ ] subjectivity........ Subjectivity Dataset v1.0
#   [ ] swadesh............. Swadesh Wordlists
#   [ ] switchboard......... Switchboard Corpus Sample
#   [ ] tagsets............. Help on Tagsets
#   [ ] timit............... TIMIT Corpus Sample
#   [ ] toolbox............. Toolbox Sample Files
#   [ ] treebank............ Penn Treebank Sample
#   [ ] twitter_samples..... Twitter Samples
#   [ ] udhr2............... Universal Declaration of Human Rights Corpus
#                            (Unicode Version)
#   [ ] udhr................ Universal Declaration of Human Rights Corpus
# Hit Enter to continue:
#   [ ] unicode_samples..... Unicode Samples
#   [ ] universal_tagset.... Mappings to the Universal Part-of-Speech Tagset
#   [ ] universal_treebanks_v20 Universal Treebanks Version 2.0
#   [ ] vader_lexicon....... VADER Sentiment Lexicon
#   [ ] verbnet3............ VerbNet Lexicon, Version 3.3
#   [ ] verbnet............. VerbNet Lexicon, Version 2.1
#   [ ] webtext............. Web Text Corpus
#   [ ] wmt15_eval.......... Evaluation data from WMT15
#   [ ] word2vec_sample..... Word2Vec Sample
#   [ ] wordnet............. WordNet
#   [ ] wordnet_ic.......... WordNet-InfoContent
#   [ ] words............... Word Lists
#   [ ] ycoe................ York-Toronto-Helsinki Parsed Corpus of Old
#                            English Prose
#
# Collections:
#   [ ] all-corpora......... All the corpora
#   [ ] all-nltk............ All packages available on nltk_data gh-pages
#                            branch
#   [ ] all................. All packages
#   [ ] book................ Everything used in the NLTK Book
#   [ ] popular............. Popular packages
# Hit Enter to continue:
#   [ ] tests............... Packages for running tests
#   [ ] third-party......... Third-party data packages
#
# ([*] marks installed packages)
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
# Hit Enter to continue:
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] crubadan............ Crubadan Corpus
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] dolch............... Dolch Word List
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] framenet_v17........ FrameNet 1.7
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
#   [ ] large_grammars...... Large context-free and feature-based grammars
#                            for parser comparison
# Hit Enter to continue:
#   [ ] lin_thesaurus....... Lin's Dependency Thesaurus
#   [ ] mac_morpho.......... MAC-MORPHO: Brazilian Portuguese news text with
#                            part-of-speech tags
#   [ ] machado............. Machado de Assis -- Obra Completa
#   [ ] masc_tagged......... MASC Tagged Corpus
#   [ ] maxent_ne_chunker... ACE Named Entity Chunker (Maximum entropy)
#   [ ] maxent_treebank_pos_tagger Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] moses_sample........ Moses Sample Models
#   [ ] movie_reviews....... Sentiment Polarity Dataset Version 2.0
#   [ ] mte_teip5........... MULTEXT-East 1984 annotated corpus 4.0
#   [ ] mwa_ppdb............ The monolingual word aligner (Sultan et al.
#                            2015) subset of the Paraphrase Database.
#   [ ] names............... Names Corpus, Version 1.3 (1994-03-29)
#   [ ] nombank.1.0......... NomBank Corpus 1.0
#   [ ] nonbreaking_prefixes Non-Breaking Prefixes (Moses Decoder)
#   [ ] nps_chat............ NPS Chat
#   [ ] omw................. Open Multilingual Wordnet
#   [ ] opinion_lexicon..... Opinion Lexicon
#   [ ] panlex_swadesh...... PanLex Swadesh Corpora
#   [ ] paradigms........... Paradigm Corpus
#   [ ] pe08................ Cross-Framework and Cross-Domain Parser
#                            Evaluation Shared Task
# Hit Enter to continue:
#   [ ] perluniprops........ perluniprops: Index of Unicode Version 7.0.0
#                            character properties in Perl
#   [ ] pil................. The Patient Information Leaflet (PIL) Corpus
#   [ ] pl196x.............. Polish language of the XX century sixties
#   [ ] porter_test......... Porter Stemmer Test Files
#   [ ] ppattach............ Prepositional Phrase Attachment Corpus
#   [ ] problem_reports..... Problem Report Corpus
#   [ ] product_reviews_1... Product Reviews (5 Products)
#   [ ] product_reviews_2... Product Reviews (9 Products)
#   [ ] propbank............ Proposition Bank Corpus 1.0
#   [ ] pros_cons........... Pros and Cons
#   [ ] ptb................. Penn Treebank
#   [ ] punkt............... Punkt Tokenizer Models
#   [ ] qc.................. Experimental Data for Question Classification
#   [ ] reuters............. The Reuters-21578 benchmark corpus, ApteMod
#                            version
#   [ ] rslp................ RSLP Stemmer (Removedor de Sufixos da Lingua
#                            Portuguesa)
#   [ ] rte................. PASCAL RTE Challenges 1, 2, and 3
#   [ ] sample_grammars..... Sample Grammars
#   [ ] semcor.............. SemCor 3.0
# Hit Enter to continue:
#   [ ] senseval............ SENSEVAL 2 Corpus: Sense Tagged Text
#   [ ] sentence_polarity... Sentence Polarity Dataset v1.0
#   [ ] sentiwordnet........ SentiWordNet
#   [ ] shakespeare......... Shakespeare XML Corpus Sample
#   [ ] sinica_treebank..... Sinica Treebank Corpus Sample
#   [ ] smultron............ SMULTRON Corpus Sample
#   [ ] snowball_data....... Snowball Data
#   [ ] spanish_grammars.... Grammars for Spanish
#   [ ] state_union......... C-Span State of the Union Address Corpus
#   [ ] stopwords........... Stopwords Corpus
#   [ ] subjectivity........ Subjectivity Dataset v1.0
#   [ ] swadesh............. Swadesh Wordlists
#   [ ] switchboard......... Switchboard Corpus Sample
#   [ ] tagsets............. Help on Tagsets
#   [ ] timit............... TIMIT Corpus Sample
#   [ ] toolbox............. Toolbox Sample Files
#   [ ] treebank............ Penn Treebank Sample
#   [ ] twitter_samples..... Twitter Samples
#   [ ] udhr2............... Universal Declaration of Human Rights Corpus
#                            (Unicode Version)
#   [ ] udhr................ Universal Declaration of Human Rights Corpus
# Hit Enter to continue:
#   [ ] unicode_samples..... Unicode Samples
#   [ ] universal_tagset.... Mappings to the Universal Part-of-Speech Tagset
#   [ ] universal_treebanks_v20 Universal Treebanks Version 2.0
#   [ ] vader_lexicon....... VADER Sentiment Lexicon
#   [ ] verbnet3............ VerbNet Lexicon, Version 3.3
#   [ ] verbnet............. VerbNet Lexicon, Version 2.1
#   [ ] webtext............. Web Text Corpus
#   [ ] wmt15_eval.......... Evaluation data from WMT15
#   [ ] word2vec_sample..... Word2Vec Sample
#   [ ] wordnet............. WordNet
#   [ ] wordnet_ic.......... WordNet-InfoContent
#   [ ] words............... Word Lists
#   [ ] ycoe................ York-Toronto-Helsinki Parsed Corpus of Old
#                            English Prose
#
# Collections:
#   [ ] all-corpora......... All the corpora
#   [ ] all-nltk............ All packages available on nltk_data gh-pages
#                            branch
#   [ ] all................. All packages
#   [ ] book................ Everything used in the NLTK Book
#   [ ] popular............. Popular packages
# Hit Enter to continue:
#   [ ] tests............... Packages for running tests
#   [ ] third-party......... Third-party data packages
#
# ([*] marks installed packages)
#
# Download which package (l=list; x=cancel)?
#   Identifier> stopword
#     Error loading stopword: Package 'stopword' not found in index
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
# Hit Enter to continue:
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] crubadan............ Crubadan Corpus
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] dolch............... Dolch Word List
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] framenet_v17........ FrameNet 1.7
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
#   [ ] large_grammars...... Large context-free and feature-based grammars
#                            for parser comparison
# Hit Enter to continue:
#   [ ] lin_thesaurus....... Lin's Dependency Thesaurus
#   [ ] mac_morpho.......... MAC-MORPHO: Brazilian Portuguese news text with
#                            part-of-speech tags
#   [ ] machado............. Machado de Assis -- Obra Completa
#   [ ] masc_tagged......... MASC Tagged Corpus
#   [ ] maxent_ne_chunker... ACE Named Entity Chunker (Maximum entropy)
#   [ ] maxent_treebank_pos_tagger Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] moses_sample........ Moses Sample Models
#   [ ] movie_reviews....... Sentiment Polarity Dataset Version 2.0
#   [ ] mte_teip5........... MULTEXT-East 1984 annotated corpus 4.0
#   [ ] mwa_ppdb............ The monolingual word aligner (Sultan et al.
#                            2015) subset of the Paraphrase Database.
#   [ ] names............... Names Corpus, Version 1.3 (1994-03-29)
#   [ ] nombank.1.0......... NomBank Corpus 1.0
#   [ ] nonbreaking_prefixes Non-Breaking Prefixes (Moses Decoder)
#   [ ] nps_chat............ NPS Chat
#   [ ] omw................. Open Multilingual Wordnet
#   [ ] opinion_lexicon..... Opinion Lexicon
#   [ ] panlex_swadesh...... PanLex Swadesh Corpora
#   [ ] paradigms........... Paradigm Corpus
#   [ ] pe08................ Cross-Framework and Cross-Domain Parser
#                            Evaluation Shared Task
# Hit Enter to continue:
#   [ ] perluniprops........ perluniprops: Index of Unicode Version 7.0.0
#                            character properties in Perl
#   [ ] pil................. The Patient Information Leaflet (PIL) Corpus
#   [ ] pl196x.............. Polish language of the XX century sixties
#   [ ] porter_test......... Porter Stemmer Test Files
#   [ ] ppattach............ Prepositional Phrase Attachment Corpus
#   [ ] problem_reports..... Problem Report Corpus
#   [ ] product_reviews_1... Product Reviews (5 Products)
#   [ ] product_reviews_2... Product Reviews (9 Products)
#   [ ] propbank............ Proposition Bank Corpus 1.0
#   [ ] pros_cons........... Pros and Cons
#   [ ] ptb................. Penn Treebank
#   [ ] punkt............... Punkt Tokenizer Models
#   [ ] qc.................. Experimental Data for Question Classification
#   [ ] reuters............. The Reuters-21578 benchmark corpus, ApteMod
#                            version
#   [ ] rslp................ RSLP Stemmer (Removedor de Sufixos da Lingua
#                            Portuguesa)
#   [ ] rte................. PASCAL RTE Challenges 1, 2, and 3
#   [ ] sample_grammars..... Sample Grammars
#   [ ] semcor.............. SemCor 3.0
# Hit Enter to continue:
#   [ ] senseval............ SENSEVAL 2 Corpus: Sense Tagged Text
#   [ ] sentence_polarity... Sentence Polarity Dataset v1.0
#   [ ] sentiwordnet........ SentiWordNet
#   [ ] shakespeare......... Shakespeare XML Corpus Sample
#   [ ] sinica_treebank..... Sinica Treebank Corpus Sample
#   [ ] smultron............ SMULTRON Corpus Sample
#   [ ] snowball_data....... Snowball Data
#   [ ] spanish_grammars.... Grammars for Spanish
#   [ ] state_union......... C-Span State of the Union Address Corpus
#   [ ] stopwords........... Stopwords Corpus
#   [ ] subjectivity........ Subjectivity Dataset v1.0
#   [ ] swadesh............. Swadesh Wordlists
#   [ ] switchboard......... Switchboard Corpus Sample
#   [ ] tagsets............. Help on Tagsets
#   [ ] timit............... TIMIT Corpus Sample
#   [ ] toolbox............. Toolbox Sample Files
#   [ ] treebank............ Penn Treebank Sample
#   [ ] twitter_samples..... Twitter Samples
#   [ ] udhr2............... Universal Declaration of Human Rights Corpus
#                            (Unicode Version)
#   [ ] udhr................ Universal Declaration of Human Rights Corpus
# Hit Enter to continue:
#   [ ] unicode_samples..... Unicode Samples
#   [ ] universal_tagset.... Mappings to the Universal Part-of-Speech Tagset
#   [ ] universal_treebanks_v20 Universal Treebanks Version 2.0
#   [ ] vader_lexicon....... VADER Sentiment Lexicon
#   [ ] verbnet3............ VerbNet Lexicon, Version 3.3
#   [ ] verbnet............. VerbNet Lexicon, Version 2.1
#   [ ] webtext............. Web Text Corpus
#   [ ] wmt15_eval.......... Evaluation data from WMT15
#   [ ] word2vec_sample..... Word2Vec Sample
#   [ ] wordnet............. WordNet
#   [ ] wordnet_ic.......... WordNet-InfoContent
#   [ ] words............... Word Lists
#   [ ] ycoe................ York-Toronto-Helsinki Parsed Corpus of Old
#                            English Prose
#
# Collections:
#   [ ] all-corpora......... All the corpora
#   [ ] all-nltk............ All packages available on nltk_data gh-pages
#                            branch
#   [ ] all................. All packages
#   [ ] book................ Everything used in the NLTK Book
#   [ ] popular............. Popular packages
# Hit Enter to continue:
#   [ ] tests............... Packages for running tests
#   [ ] third-party......... Third-party data packages
#
# ([*] marks installed packages)
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
#   [ ] comtrans............ ComTrans Corpus Sample
#   [ ] conll2000........... CONLL 2000 Chunking Corpus
#   [ ] conll2002........... CONLL 2002 Named Entity Recognition Corpus
# Hit Enter to continue:
#   [ ] conll2007........... Dependency Treebanks from CoNLL 2007 (Catalan
#                            and Basque Subset)
#   [ ] crubadan............ Crubadan Corpus
#   [ ] dependency_treebank. Dependency Parsed Treebank
#   [ ] dolch............... Dolch Word List
#   [ ] europarl_raw........ Sample European Parliament Proceedings Parallel
#                            Corpus
#   [ ] floresta............ Portuguese Treebank
#   [ ] framenet_v15........ FrameNet 1.5
#   [ ] framenet_v17........ FrameNet 1.7
#   [ ] gazetteers.......... Gazeteer Lists
#   [ ] genesis............. Genesis Corpus
#   [ ] gutenberg........... Project Gutenberg Selections
#   [ ] ieer................ NIST IE-ER DATA SAMPLE
#   [ ] inaugural........... C-Span Inaugural Address Corpus
#   [ ] indian.............. Indian Language POS-Tagged Corpus
#   [ ] jeita............... JEITA Public Morphologically Tagged Corpus (in
#                            ChaSen format)
#   [ ] kimmo............... PC-KIMMO Data Files
#   [ ] knbc................ KNB Corpus (Annotated blog corpus)
#   [ ] large_grammars...... Large context-free and feature-based grammars
#                            for parser comparison
# Hit Enter to continue:
#   [ ] lin_thesaurus....... Lin's Dependency Thesaurus
#   [ ] mac_morpho.......... MAC-MORPHO: Brazilian Portuguese news text with
#                            part-of-speech tags
#   [ ] machado............. Machado de Assis -- Obra Completa
#   [ ] masc_tagged......... MASC Tagged Corpus
#   [ ] maxent_ne_chunker... ACE Named Entity Chunker (Maximum entropy)
#   [ ] maxent_treebank_pos_tagger Treebank Part of Speech Tagger (Maximum entropy)
#   [ ] moses_sample........ Moses Sample Models
#   [ ] movie_reviews....... Sentiment Polarity Dataset Version 2.0
#   [ ] mte_teip5........... MULTEXT-East 1984 annotated corpus 4.0
#   [ ] mwa_ppdb............ The monolingual word aligner (Sultan et al.
#                            2015) subset of the Paraphrase Database.
#   [ ] names............... Names Corpus, Version 1.3 (1994-03-29)
#   [ ] nombank.1.0......... NomBank Corpus 1.0
#   [ ] nonbreaking_prefixes Non-Breaking Prefixes (Moses Decoder)
#   [ ] nps_chat............ NPS Chat
#   [ ] omw................. Open Multilingual Wordnet
#   [ ] opinion_lexicon..... Opinion Lexicon
#   [ ] panlex_swadesh...... PanLex Swadesh Corpora
#   [ ] paradigms........... Paradigm Corpus
#   [ ] pe08................ Cross-Framework and Cross-Domain Parser
#                            Evaluation Shared Task
# Hit Enter to continue:
#   [ ] perluniprops........ perluniprops: Index of Unicode Version 7.0.0
#                            character properties in Perl
#   [ ] pil................. The Patient Information Leaflet (PIL) Corpus
#   [ ] pl196x.............. Polish language of the XX century sixties
#   [ ] porter_test......... Porter Stemmer Test Files
#   [ ] ppattach............ Prepositional Phrase Attachment Corpus
#   [ ] problem_reports..... Problem Report Corpus
#   [ ] product_reviews_1... Product Reviews (5 Products)
#   [ ] product_reviews_2... Product Reviews (9 Products)
#   [ ] propbank............ Proposition Bank Corpus 1.0
#   [ ] pros_cons........... Pros and Cons
#   [ ] ptb................. Penn Treebank
#   [ ] punkt............... Punkt Tokenizer Models
#   [ ] qc.................. Experimental Data for Question Classification
#   [ ] reuters............. The Reuters-21578 benchmark corpus, ApteMod
#                            version
#   [ ] rslp................ RSLP Stemmer (Removedor de Sufixos da Lingua
#                            Portuguesa)
#   [ ] rte................. PASCAL RTE Challenges 1, 2, and 3
#   [ ] sample_grammars..... Sample Grammars
#   [ ] semcor.............. SemCor 3.0
# Hit Enter to continue:
#   [ ] senseval............ SENSEVAL 2 Corpus: Sense Tagged Text
#   [ ] sentence_polarity... Sentence Polarity Dataset v1.0
#   [ ] sentiwordnet........ SentiWordNet
#   [ ] shakespeare......... Shakespeare XML Corpus Sample
#   [ ] sinica_treebank..... Sinica Treebank Corpus Sample
#   [ ] smultron............ SMULTRON Corpus Sample
#   [ ] snowball_data....... Snowball Data
#   [ ] spanish_grammars.... Grammars for Spanish
#   [ ] state_union......... C-Span State of the Union Address Corpus
#   [ ] stopwords........... Stopwords Corpus
#   [ ] subjectivity........ Subjectivity Dataset v1.0
#   [ ] swadesh............. Swadesh Wordlists
#   [ ] switchboard......... Switchboard Corpus Sample
#   [ ] tagsets............. Help on Tagsets
#   [ ] timit............... TIMIT Corpus Sample
#   [ ] toolbox............. Toolbox Sample Files
#   [ ] treebank............ Penn Treebank Sample
#   [ ] twitter_samples..... Twitter Samples
#   [ ] udhr2............... Universal Declaration of Human Rights Corpus
#                            (Unicode Version)
#   [ ] udhr................ Universal Declaration of Human Rights Corpus
# Hit Enter to continue:
#   [ ] unicode_samples..... Unicode Samples
#   [ ] universal_tagset.... Mappings to the Universal Part-of-Speech Tagset
#   [ ] universal_treebanks_v20 Universal Treebanks Version 2.0
#   [ ] vader_lexicon....... VADER Sentiment Lexicon
#   [ ] verbnet3............ VerbNet Lexicon, Version 3.3
#   [ ] verbnet............. VerbNet Lexicon, Version 2.1
#   [ ] webtext............. Web Text Corpus
#   [ ] wmt15_eval.......... Evaluation data from WMT15
#   [ ] word2vec_sample..... Word2Vec Sample
#   [ ] wordnet............. WordNet
#   [ ] wordnet_ic.......... WordNet-InfoContent
#   [ ] words............... Word Lists
#   [ ] ycoe................ York-Toronto-Helsinki Parsed Corpus of Old
#                            English Prose
#
# Collections:
#   [ ] all-corpora......... All the corpora
#   [ ] all-nltk............ All packages available on nltk_data gh-pages
#                            branch
#   [ ] all................. All packages
#   [ ] book................ Everything used in the NLTK Book
#   [ ] popular............. Popular packages
# Hit Enter to continue:
#   [ ] tests............... Packages for running tests
#   [ ] third-party......... Third-party data packages
#
# ([*] marks installed packages)
#
# Download which package (l=list; x=cancel)?
#   Identifier> stopword
#     Error loading stopword: Package 'stopword' not found in index
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
df=pd.read_csv("fake_job_postings.csv")

# %%
df.head()
# Out:
#    job_id  ... fraudulent
# 0       1  ...          0
# 1       2  ...          0
# 2       3  ...          0
# 3       4  ...          0
# 4       5  ...          0
#
# [5 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15185 non-null  object
#  8   benefits             10670 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
#  15  industry             12977 non-null  object
#  16  function             11425 non-null  object
#  17  fraudulent           17880 non-null  int64
# dtypes: int64(5), object(13)
# memory usage: 2.5+ MB

# %%
df["fraudulent"].value_counts()
# Out:
# 0    17014
# 1      866
# Name: fraudulent, dtype: int64

# %%
df["title"].nunique()
# Out:
# 11231

# %%
split_location=df["location"].apply(lambda x:str(x).strip().split(','))
split_location=split_location.apply(pd.Series)

# %% [markdown]
# Split Location

# %%
split_location
# Out:
#        0    1              2    3    4    5   ...   10   11   12   13   14   15
# 0      US   NY       New York  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1      NZ            Auckland  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 2      US   IA          Wever  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 3      US   DC     Washington  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 4      US   FL     Fort Worth  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ..  ...            ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 17875  CA   ON        Toronto  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 17876  US   PA   Philadelphia  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 17877  US   TX        Houston  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 17878  NG   LA          Lagos  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 17879  NZ    N     Wellington  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN
#
# [17880 rows x 16 columns]

# %%
split_location[~(split_location[4].isnull())]
# Out:
#        0    1                    2   ...        13          14           15
# 733    US   AL           Birmingham  ...       NaN         NaN          NaN
# 1725   US   TX               Austin  ...       NaN         NaN          NaN
# 4396   US   MI             Hartford  ...       NaN         NaN          NaN
# 4480   US   CA             San Jose  ...       NaN         NaN          NaN
# 4527   US   NJ             Lakewood  ...       NaN         NaN          NaN
# 4650   US   FL           Central Fl  ...       NaN         NaN          NaN
# 11987  US   CA          Los Angeles  ...       NaN         NaN          NaN
# 12383  NL   ZH            Rotterdam  ...       NaN         NaN          NaN
# 12467  US   NJ             Lakewood  ...       NaN         NaN          NaN
# 13181  US   CA          Los Angeles  ...   Arizona   San Diego   California
# 13353  NL   NH            Amsterdam  ...       NaN         NaN          NaN
# 13729  US   IL              Chicago  ...       NaN         NaN          NaN
# 14070  US   CO               Denver  ...       NaN         NaN          NaN
# 14561  GB        Welwyn Garden City  ...       NaN         NaN          NaN
# 14619  NL   ZH            Rotterdam  ...       NaN         NaN          NaN
# 17571  US   FL              Orlando  ...       NaN         NaN          NaN
#
# [16 rows x 16 columns]

# %%
df['country']=split_location[0]

# %%
df['location_count']=df["location"].apply(lambda x:str(x).split(', '))

# %%
df['location_count']=df['location_count'].apply(lambda x:max(len(x)-2,0))

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x='location_count',data=df,hue='fraudulent')
for p in ax.patches:
        ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))

# %%
df[((df['telecommuting']==1)&(df['location']!='none'))]['job_id'].count()
# Out:
# 767

# %%
df[((df['telecommuting']==0)&(df['location'].isnull()))]['job_id'].count()
# Out:
# 325

# %% [markdown]
# Missing Location

# %%
df['null_count']=df.isnull().sum(axis=1)

# %%
sns.countplot(x='null_count',data=df,hue='fraudulent');

# %%
df['department'].value_counts().head(20)
# Out:
# Sales                     551
# Engineering               487
# Marketing                 401
# Operations                270
# IT                        225
# Development               146
# Product                   112
# Information Technology     86
# Design                     76
# Technology                 76
# Customer Service           73
# Finance                    69
# HR                         56
# tech                       55
# R&D                        54
# Creative                   48
# Retail                     45
# Client Services            45
# Product Development        36
# Oil and Gas                32
# Name: department, dtype: int64

# %%
df['department'].fillna('none',inplace=True)

# %%
sns.countplot(x='department',data=df[((df['department']=='tech')|(df['department']=='Technology'))],hue='fraudulent');

# %%
sns.countplot(x='department',data=df[((df['department']=='IT')|(df['department']=='Information Technology'))],hue='fraudulent');

# %%
sns.countplot(x='department',data=df[((df['department']=='Development')|(df['department']=='Product')|(df['department']=='Product Development'))],hue='fraudulent');

# %%
sns.countplot(x='department',data=df[df['department']=='none'],hue='fraudulent');

# %%
df['salary_range'].nunique()
# Out:
# 874

# %%
df[df['salary_range'].notnull()]['salary_range']
# Out:
# 6          20000-28000
# 10       100000-120000
# 15       120000-150000
# 23       100000-120000
# 31         50000-65000
#              ...
# 17844              0-0
# 17849     80000-100000
# 17865      18000-20000
# 17867      18000-19000
# 17874     80000-100000
# Name: salary_range, Length: 2868, dtype: object

# %%
salary=df['salary_range'].apply(lambda x:str(x).strip().split('-'))
salary=salary.apply(pd.Series)

# %%
# Function to check fot non integer values
def int_check(x):
    try:
        int(x)
    except:
        if x!='nan':
            print(x)

# %%
salary[0].apply(int_check)
# Out:
# Oct
# Oct
# Jun
# Oct
# Dec
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 17875    None
# 17876    None
# 17877    None
# 17878    None
# 17879    None
# Name: 0, Length: 17880, dtype: object

# %%
def int_convert(x):
    try:
        return int(x)
    except:
        return 0

# %%
df['salary_lower_bound']=salary[0]
df['salary_lower_bound']=df['salary_lower_bound'].apply(int_convert)
df['salary_upper_bound']=salary[1]
df['salary_upper_bound']=df['salary_upper_bound'].apply(int_convert)

# %%
df['avg_salary']=(df['salary_upper_bound']+df['salary_lower_bound'])/2

# %%
px.histogram(data_frame=df[(df['avg_salary']<=100000)&(df['avg_salary']!=0)],x="avg_salary",color='fraudulent',marginal='rug')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e104d8e5-1fa5-4cb1-a124-dafaeddca809" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e104d8e5-1fa5-4cb1-a124-dafaeddca809")) {
#                     Plotly.newPlot(
#                         'e104d8e5-1fa5-4cb1-a124-dafaeddca809',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "fraudulent=0<br>avg_salary=%{x}<br>count=%{y}", "legendgroup": "fraudulent=0", "marker": {"color": "#636efa"}, "name": "fraudulent=0", "offsetgroup": "fraudulent=0", "orientation": "v", "showlegend": true, "type": "histogram", "x": [24000.0, 57500.0, 45000.0, 70.0, 67500.0, 95.0, 92500.0, 18500.0, 22000.0, 16500.0, 60000.0, 52500.0, 35000.0, 80000.0, 12000.0, 80.0, 36500.0, 17150.0, 37500.0, 4.5, 50500.0, 23250.0, 65000.0, 32500.0, 30000.0, 65000.0, 35000.0, 65000.0, 90000.0, 35000.0, 65000.0, 35000.0, 15750.0, 35000.0, 52500.0, 47500.0, 33500.0, 56000.0, 67500.0, 90000.0, 52500.0, 55000.0, 80000.0, 45000.0, 30000.0, 500.0, 38000.0, 95000.0, 90000.0, 19000.0, 45000.0, 90000.0, 48500.0, 65000.0, 92500.0, 12000.0, 35000.0, 33000.0, 1650.0, 55000.0, 50000.0, 36000.0, 57500.0, 75.0, 56000.0, 13000.0, 107.5, 95000.0, 14500.0, 50000.0, 10500.0, 70000.0, 95000.0, 33500.0, 50000.0, 67500.0, 80000.0, 27500.0, 65000.0, 18500.0, 19000.0, 26000.0, 5500.0, 19000.0, 44000.0, 11000.0, 100000.0, 65000.0, 10800.0, 55000.0, 32500.0, 47500.0, 61000.0, 92500.0, 80000.0, 97500.0, 37000.0, 65000.0, 65000.0, 97500.0, 20000.0, 65000.0, 30000.0, 19500.0, 57500.0, 67500.0, 62500.0, 35000.0, 45000.0, 55000.0, 80000.0, 35000.0, 55000.0, 35000.0, 27500.0, 70000.0, 23000.0, 13800.0, 34000.0, 105.0, 5000.5, 24000.0, 37500.0, 15750.0, 67500.0, 95000.0, 47500.0, 40000.0, 100000.0, 25000.0, 95000.0, 10500.0, 87.5, 1161.0, 42000.0, 40000.0, 45000.0, 60000.0, 40000.0, 70000.0, 40.0, 17500.0, 55000.0, 23000.0, 37500.0, 17250.0, 20000.0, 42500.0, 31500.0, 92500.0, 49500.0, 60000.0, 51.5, 100000.0, 40000.0, 52500.0, 25000.0, 35000.0, 34500.0, 42500.0, 50000.0, 60000.0, 45000.0, 28000.0, 56000.0, 40000.0, 60000.0, 33600.0, 100000.0, 25000.0, 43000.0, 112.5, 8000.0, 60000.0, 45000.0, 26000.0, 4500.0, 37500.0, 95000.0, 72500.0, 85.0, 77500.0, 40000.0, 22500.0, 75000.0, 35000.0, 25560.0, 45000.0, 52800.0, 70000.0, 90000.0, 35000.0, 45000.0, 93000.0, 50000.0, 28000.0, 35000.0, 500.0, 65000.0, 70000.0, 85000.0, 55000.0, 27500.0, 1500.0, 50000.0, 55000.0, 77500.0, 50000.0, 10500.0, 20000.0, 30000.0, 40000.0, 85000.0, 22500.0, 45000.0, 15000.0, 16000.0, 22500.0, 35000.0, 45000.0, 95000.0, 16000.0, 61058.5, 100000.0, 75000.0, 70000.0, 17000.0, 21500.0, 15000.0, 42500.0, 1.5, 12500.0, 80000.0, 32750.0, 65000.0, 22500.0, 65000.0, 25500.0, 47500.0, 100000.0, 54500.0, 2.0, 49194.0, 12000.0, 17250.0, 15600.0, 1600.0, 60000.0, 4500.0, 30500.0, 19000.0, 9000.0, 4500.0, 45000.0, 27500.0, 100000.0, 56000.0, 55000.0, 70000.0, 72500.0, 55000.0, 75000.0, 21500.0, 150.0, 25000.0, 95000.0, 45000.0, 1150.0, 16500.0, 60000.0, 45000.0, 98000.0, 40000.0, 45000.0, 33500.0, 33500.0, 31000.0, 18000.0, 60000.0, 95000.0, 97500.0, 40000.0, 45000.0, 1075.0, 45000.0, 75000.0, 21000.0, 60000.0, 10050.0, 49194.0, 7.5, 52500.0, 42500.0, 95000.0, 70000.0, 1000.0, 40000.0, 4500.0, 21500.0, 47500.0, 37500.0, 57500.0, 70000.0, 4500.0, 16000.0, 30000.0, 50000.0, 45000.0, 33500.0, 100000.0, 59500.0, 60.0, 45000.0, 27500.0, 40000.0, 22500.0, 52500.0, 75000.0, 10500.0, 90000.0, 100000.0, 35000.0, 87500.0, 90000.0, 90000.0, 37500.0, 32500.0, 28050.0, 45000.0, 100000.0, 45000.0, 80000.0, 27500.0, 40000.0, 47500.0, 20500.0, 45000.0, 13395.0, 25000.0, 57500.0, 42500.0, 40000.0, 4500.0, 47500.0, 65000.0, 45000.0, 134.0, 60000.0, 25000.0, 40000.0, 50000.0, 21000.0, 25560.0, 37400.0, 53500.0, 80000.0, 32500.0, 15500.0, 20000.0, 50000.0, 69500.0, 35000.0, 35000.0, 52500.0, 40000.0, 40000.0, 45000.0, 34000.0, 15000.0, 45000.0, 80000.0, 20500.0, 90000.0, 77500.0, 67500.0, 32500.0, 26000.0, 37500.0, 62500.0, 17500.0, 40000.0, 45000.0, 90000.0, 27500.0, 52500.0, 95000.0, 39000.0, 18000.0, 90000.0, 67500.0, 45000.0, 22500.0, 70000.0, 50000.0, 60.0, 90000.0, 17250.0, 75000.0, 52500.0, 87500.0, 52000.0, 26000.0, 24500.0, 67500.0, 37500.0, 70000.0, 87000.0, 57500.0, 17000.0, 42500.0, 55000.0, 97500.0, 4500.0 ...

# %%
sns.countplot(x='telecommuting',data=df,hue='fraudulent');

# %%
sns.barplot(x="has_company_logo", y="percentage", hue="fraudulent", data=df.groupby(['fraudulent'])['has_company_logo']
                     .value_counts(normalize=True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values('has_company_logo'));

# %% [markdown]
# Company tanpa Logo

# %%
sns.barplot(x="has_questions", y="percentage", hue="fraudulent", data=df.groupby(['fraudulent'])['has_questions']
                     .value_counts(normalize=True)
                     .rename('percentage')
                     .mul(100)
                     .reset_index()
                     .sort_values('has_questions'));

# %%
df['employment_type'].unique()
# Out:
# array(['Other', 'Full-time', nan, 'Part-time', 'Contract', 'Temporary'],
#       dtype=object)

# %%
df['employment_type'].fillna("none",inplace=True)

# %%
sns.countplot(x='employment_type',data=df);

# %%
df['required_experience'].unique()
# Out:
# array(['Internship', 'Not Applicable', nan, 'Mid-Senior level',
#        'Associate', 'Entry level', 'Executive', 'Director'], dtype=object)

# %%
df[df['required_experience']=='Not Applicable'].head()
# Out:
#      job_id  ... avg_salary
# 1         2  ...        0.0
# 13       14  ...        0.0
# 59       60  ...        0.0
# 94       95  ...        0.0
# 107     108  ...    60000.0
#
# [5 rows x 24 columns]

# %%
df[df['required_experience'].isnull()].head()
# Out:
#     job_id  ... avg_salary
# 2        3  ...        0.0
# 5        6  ...        0.0
# 7        8  ...        0.0
# 11      12  ...        0.0
# 17      18  ...        0.0
#
# [5 rows x 24 columns]

# %% [markdown]
# Missing requirements

# %%
df['required_experience'].fillna('Not Applicable',inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='required_experience',data=df);

# %%
df['required_education'].unique()
# Out:
# array([nan, "Bachelor's Degree", "Master's Degree",
#        'High School or equivalent', 'Unspecified',
#        'Some College Coursework Completed', 'Vocational', 'Certification',
#        'Associate Degree', 'Professional', 'Doctorate',
#        'Some High School Coursework', 'Vocational - Degree',
#        'Vocational - HS Diploma'], dtype=object)

# %%
df['required_education'].fillna('Unspecified',inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.countplot(y='required_education',data=df,hue='fraudulent');

# %%
df['industry'].unique()
# Out:
# array([nan, 'Marketing and Advertising', 'Computer Software',
#        'Hospital & Health Care', 'Online Media',
#        'Information Technology and Services', 'Financial Services',
#        'Management Consulting', 'Events Services', 'Internet',
#        'Facilities Services', 'Consumer Electronics',
#        'Telecommunications', 'Consumer Services', 'Construction',
#        'Oil & Energy', 'Education Management', 'Building Materials',
#        'Banking', 'Food & Beverages', 'Food Production',
#        'Health, Wellness and Fitness', 'Insurance', 'E-Learning',
#        'Cosmetics', 'Staffing and Recruiting',
#        'Venture Capital & Private Equity', 'Leisure, Travel & Tourism',
#        'Human Resources', 'Pharmaceuticals', 'Farming', 'Legal Services',
#        'Luxury Goods & Jewelry', 'Machinery', 'Real Estate',
#        'Mechanical or Industrial Engineering',
#        'Public Relations and Communications', 'Consumer Goods',
#        'Medical Practice', 'Electrical/Electronic Manufacturing',
#        'Hospitality', 'Music', 'Market Research', 'Automotive',
#        'Philanthropy', 'Utilities', 'Primary/Secondary Education',
#        'Logistics and Supply Chain', 'Design', 'Gambling & Casinos',
#        'Accounting', 'Environmental Services', 'Mental Health Care',
#        'Investment Management', 'Apparel & Fashion', 'Media Production',
#        'Publishing', 'Medical Devices', 'Information Services', 'Retail',
#        'Sports', 'Computer Games', 'Chemicals', 'Aviation & Aerospace',
#        'Business Supplies and Equipment', 'Program Development',
#        'Computer Networking', 'Biotechnology',
#        'Civic & Social Organization', 'Religious Institutions',
#        'Warehousing', 'Airlines/Aviation', 'Writing and Editing',
#        'Restaurants', 'Outsourcing/Offshoring',
#        'Transportation/Trucking/Railroad', 'Wireless',
#        'Investment Banking', 'Nonprofit Organization Management',
#        'Libraries', 'Computer Hardware', 'Broadcast Media', 'Printing',
#        'Graphic Design', 'Entertainment', 'Wholesale', 'Research',
#        'Animation', 'Government Administration', 'Capital Markets',
#        'Computer & Network Security', 'Semiconductors',
#        'Security and Investigations', 'Architecture & Planning',
#        'Maritime', 'Fund-Raising', 'Higher Education',
#        'Renewables & Environment', 'Motion Pictures and Film',
#        'Law Practice', 'Government Relations', 'Packaging and Containers',
#        'Sporting Goods', 'Mining & Metals', 'Import and Export',
#        'International Trade and Development',
#        'Professional Training & Coaching', 'Textiles',
#        'Commercial Real Estate', 'Law Enforcement',
#        'Package/Freight Delivery', 'Translation and Localization',
#        'Photography', 'Industrial Automation', 'Wine and Spirits',
#        'Public Safety', 'Civil Engineering', 'Military',
#        'Defense & Space', 'Veterinary', 'Executive Office',
#        'Performing Arts', 'Individual & Family Services', 'Public Policy',
#        'Nanotechnology', 'Museums and Institutions', 'Fishery',
#        'Plastics', 'Furniture', 'Shipbuilding',
#        'Alternative Dispute Resolution', 'Ranching'], dtype=object)

# %%
df['industry'].fillna('not specified',inplace=True)

# %%
df[(df['company_profile'].isnull())&(df['fraudulent']==0)]
# Out:
#        job_id  ... avg_salary
# 5           6  ...        0.0
# 10         11  ...   110000.0
# 24         25  ...        0.0
# 31         32  ...    57500.0
# 37         38  ...        0.0
# ...       ...  ...        ...
# 17867   17868  ...    18500.0
# 17869   17870  ...        0.0
# 17873   17874  ...        0.0
# 17874   17875  ...    90000.0
# 17878   17879  ...        0.0
#
# [2721 rows x 24 columns]

# %%
abbr_dict={
    "what's":"what is",
    "what're":"what are",
    "who's":"who is",
    "who're":"who are",
    "where's":"where is",
    "where're":"where are",
    "when's":"when is",
    "when're":"when are",
    "how's":"how is",
    "how're":"how are",

    "i'm":"i am",
    "we're":"we are",
    "you're":"you are",
    "they're":"they are",
    "it's":"it is",
    "he's":"he is",
    "she's":"she is",
    "that's":"that is",
    "there's":"there is",
    "there're":"there are",

    "i've":"i have",
    "we've":"we have",
    "you've":"you have",
    "they've":"they have",
    "who've":"who have",
    "would've":"would have",
    "not've":"not have",

    "i'll":"i will",
    "we'll":"we will",
    "you'll":"you will",
    "he'll":"he will",
    "she'll":"she will",
    "it'll":"it will",
    "they'll":"they will",

    "isn't":"is not",
    "wasn't":"was not",
    "aren't":"are not",
    "weren't":"were not",
    "can't":"can not",
    "couldn't":"could not",
    "don't":"do not",
    "didn't":"did not",
    "shouldn't":"should not",
    "wouldn't":"would not",
    "doesn't":"does not",
    "haven't":"have not",
    "hasn't":"has not",
    "hadn't":"had not",
    "won't":"will not",
}

stop_words=stopwords.words('english')
lemmatizer = WordNetLemmatizer() 

def text_preprocess(x):
    if pd.isnull(x) or x=='nan':
        return "not specified"
    x=str(x)
    x=x.lower()
    #remove url,email,phone number and links
    x=re.sub("(#url_.*#)|(#email.*#)|(#phone.*#)|((http|https)://\w*)",' ',x)
    # remove abbreviations
    pattern = re.compile(r'\b(' + '|'.join(abbr_dict.keys()) + r')\b')
    x = pattern.sub(lambda x: abbr_dict[x.group()], x)
    tokens = re.findall("[\w']+", x)
    tokens=[word for word in tokens if ((word not in stop_words) and (len(word)>1) and not(word.isdigit()))]
    lemmatized_tokens=list(map(lemmatizer.lemmatize,tokens))
    string=""
    for word in lemmatized_tokens:
        string+=word+' '
    return string

# %%
df['text']=df[['title', 'company_profile', 'description','requirements','benefits']].fillna('').agg(' '.join, axis=1)

# %%
df['text_length']=df['text'].apply(lambda x:len(x.split()))

# %%
px.histogram(data_frame=df,x="text_length",color='fraudulent',marginal='rug')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a65b2de6-0f36-49c6-aace-55efd0c7d8ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a65b2de6-0f36-49c6-aace-55efd0c7d8ff")) {
#                     Plotly.newPlot(
#                         'a65b2de6-0f36-49c6-aace-55efd0c7d8ff',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "fraudulent=0<br>text_length=%{x}<br>count=%{y}", "legendgroup": "fraudulent=0", "marker": {"color": "#636efa"}, "name": "fraudulent=0", "offsetgroup": "fraudulent=0", "orientation": "v", "showlegend": true, "type": "histogram", "x": [382, 901, 359, 709, 470, 482, 336, 710, 245, 335, 664, 430, 397, 272, 311, 740, 179, 209, 301, 377, 495, 704, 717, 505, 52, 1009, 304, 188, 242, 333, 533, 164, 446, 433, 201, 67, 65, 307, 485, 424, 67, 68, 54, 258, 519, 444, 932, 347, 67, 339, 180, 390, 204, 266, 431, 228, 430, 859, 289, 397, 76, 574, 67, 405, 319, 640, 140, 125, 383, 225, 209, 320, 328, 61, 313, 573, 440, 339, 1227, 379, 67, 419, 279, 378, 295, 594, 378, 382, 686, 67, 388, 362, 274, 290, 259, 310, 389, 303, 67, 176, 67, 109, 329, 67, 768, 241, 523, 337, 556, 370, 345, 337, 342, 566, 240, 536, 165, 425, 67, 474, 207, 67, 67, 324, 262, 522, 470, 455, 527, 293, 280, 174, 67, 464, 67, 295, 113, 421, 326, 67, 351, 204, 82, 176, 295, 158, 443, 708, 371, 67, 871, 457, 225, 497, 72, 67, 331, 160, 391, 256, 398, 392, 208, 609, 174, 298, 322, 313, 183, 751, 1289, 288, 325, 68, 316, 402, 53, 67, 394, 131, 400, 271, 422, 188, 67, 67, 298, 276, 628, 490, 294, 504, 67, 384, 456, 430, 584, 421, 67, 62, 256, 456, 464, 374, 67, 326, 330, 643, 348, 344, 1185, 67, 720, 483, 438, 608, 239, 247, 67, 454, 275, 67, 92, 315, 479, 333, 67, 239, 723, 292, 246, 851, 67, 180, 324, 338, 431, 396, 65, 507, 457, 67, 478, 473, 598, 280, 395, 117, 65, 159, 340, 411, 567, 320, 301, 247, 163, 405, 266, 181, 410, 1031, 330, 133, 67, 260, 270, 105, 67, 232, 451, 559, 353, 65, 731, 67, 632, 471, 538, 67, 491, 243, 401, 686, 343, 353, 595, 67, 432, 738, 580, 214, 466, 384, 328, 445, 306, 180, 143, 497, 67, 521, 322, 114, 67, 619, 326, 103, 67, 611, 1034, 832, 583, 707, 530, 542, 311, 492, 372, 615, 331, 67, 516, 67, 575, 66, 324, 311, 194, 421, 283, 330, 277, 76, 287, 847, 311, 644, 310, 66, 154, 300, 67, 236, 269, 838, 210, 220, 799, 19, 510, 371, 338, 340, 346, 879, 511, 611, 141, 67, 485, 246, 49, 423, 300, 824, 542, 375, 650, 412, 401, 482, 356, 462, 176, 338, 191, 74, 122, 355, 67, 226, 715, 148, 461, 292, 472, 423, 504, 221, 205, 499, 393, 415, 436, 308, 444, 377, 55, 458, 340, 94, 584, 355, 361, 245, 381, 249, 315, 66, 359, 139, 286, 491, 423, 68, 442, 432, 121, 499, 425, 243, 354, 279, 649, 273, 414, 69, 240, 23, 68, 68, 432, 425, 273, 101, 236, 231, 68, 331, 299, 343, 191, 602, 544, 206, 867, 442, 313, 323, 298, 323, 302, 271, 502, 305, 68, 172, 663, 370, 336, 522, 342, 254, 419, 508, 78, 67, 51, 267, 347, 524, 323, 324, 328, 709, 395, 314, 344, 397, 48, 332, 593, 264, 490, 495, 767, 183, 332, 325, 356, 480, 441, 31, 430, 85, 67, 582, 255, 84, 328, 67, 385, 228, 595, 67, 152, 271, 371, 611, 348, 32, 287, 422, 65, 311, 243, 385, 653, 253, 386, 496, 434, 292, 116, 617, 741, 67, 153, 336, 507, 515, 85, 653, 473, 99, 371, 74, 394, 342, 328, 48, 345, 67, 503, 52, 428, 74, 67, 166, 69, 349, 282, 352, 140, 913, 349, 345, 524, 426, 67, 67, 425, 724, 1257, 496, 74, 67, 344, 685, 608, 315, 444, 340, 608, 374, 472, 67, 572, 367, 697, 77, 67, 68, 368, 376, 68, 326, 363, 421, 435, 338, 410, 600, 450, 396, 302, 497, 433, 243, 447, 606, 499, 306, 325, 246, 88, 430, 121, 109, 67, 527, 467, 298, 456, 187, 526, 838, 198, 423, 164, 683, 211, 408, 270, 282, 479, 298, 359, 340, 140, 457, 339, 353, 247, 519, 68, 470, 426, 66, 405, 443, 130, 318, 686, 248, 411, 131, 471, 726, 490, 553, 568, 234, 687, 710, 451, 67, 188, 457, 355, 364, 498, 331, 103, 326, 803, 187, 132, 523, 180, 307, 252, 441, 727, 67, 320, 471, 67, 427, 386, 780, 67, 67, 444, 311, 423, 67, 67, 491, 574, 491, 67, 177, 302, 300, 550, 430, 67, 14, 448, 423, 444, 392, 416, 878, 970, 475, 141, 807, 1227, 186, 709, 430, 450, 184, 475, 546, 283, 173, 90, 330, 726, 433, 152, 67, 590, 67, 404, 120, 410, 382, 67, 249, 679, 446, 219, 377, 380, 616, 67, 763, 465, 807, 432, 530, 321, 265, 460, 408, 255, 295, 1 ...

# %%
x_train,x_test,y_train,y_test=train_test_split(df, df['fraudulent'], test_size=0.2,stratify=df['fraudulent'], random_state=42)

# %%
numerical_features=['telecommuting','has_company_logo','has_questions','location_count','null_count','text_length']

scaler=StandardScaler()
num_train=csr_matrix(scaler.fit_transform(x_train[numerical_features]))
num_test=csr_matrix(scaler.transform(x_test[numerical_features]))

# %%
ohe=OneHotEncoder()
ohe_train=ohe.fit_transform(x_train[['required_education','employment_type','required_experience']])
ohe_test=ohe.transform(x_test[['required_education','employment_type','required_experience']])

# %%
bow=CountVectorizer(ngram_range=(1,2))
text_train=bow.fit_transform(x_train['text'])
text_test=bow.transform(x_test['text'])

# %%
combined_train=hstack([num_train,ohe_train])
combined_test=hstack([num_test,ohe_test])
combined_train=hstack([combined_train,text_train])
combined_test=hstack([combined_test,text_test])

# %%
params={'C':[1,10,100,1000]}
clf=LogisticRegression(solver='liblinear',class_weight='balanced')
grid=GridSearchCV(clf,params,scoring='f1',n_jobs=-1,cv=5)
grid.fit(combined_train,y_train)
print(f1_score(y_train,grid.predict(combined_train)))
print(f1_score(y_test,grid.predict(combined_test)))
print(confusion_matrix(y_train,grid.predict(combined_train)))
print(confusion_matrix(y_test,grid.predict(combined_test)))
# Out:
# 1.0
# 0.8802395209580838
# [[13611     0]
#  [    0   693]]
# [[3389   14]
#  [  26  147]]

# %%
tfidf=TfidfVectorizer(ngram_range=(1,2))
text_train=tfidf.fit_transform(x_train['text'])
text_test=tfidf.transform(x_test['text'])

# %%
combined_train=hstack([num_train,ohe_train])
combined_test=hstack([num_test,ohe_test])
combined_train=hstack([combined_train,text_train])
combined_test=hstack([combined_test,text_test])

# %%
params={'C':[1,10,100,1000]}
clf=LogisticRegression(solver='liblinear',class_weight='balanced')
grid=GridSearchCV(clf,params,scoring='f1',n_jobs=-1,cv=5)
grid.fit(combined_train,y_train)
print(f1_score(y_train,grid.predict(combined_train)))
print(f1_score(y_test,grid.predict(combined_test)))
print(confusion_matrix(y_train,grid.predict(combined_train)))
print(confusion_matrix(y_test,grid.predict(combined_test)))
# Out:
# 1.0
# 0.9361702127659575
# [[13611     0]
#  [    0   693]]
# [[3401    2]
#  [  19  154]]

# %%
embeddings_index = {}
f = open('fake_job_postings.csv','r',encoding='utf-8')
for line in tqdm(f):
    values = line.split(' ')
    word = values[0]
    coefs = np.asarray(values[1:], dtype='object')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# 17881it [00:01, 16394.02it/s]
# Found 17881 word vectors.

# %%
combined_train=hstack([num_train,ohe_train])
combined_test=hstack([num_test,ohe_test])
combined_train=hstack([combined_train,text_train])
combined_test=hstack([combined_test,text_test])

# %%
params={'C':[0.01,0.1,1,10]}
clf=LogisticRegression(solver='liblinear',class_weight='balanced')
grid=GridSearchCV(clf,params,scoring='f1',n_jobs=-1,cv=5)
grid.fit(combined_train,y_train)
print(f1_score(y_train,grid.predict(combined_train)))
print(f1_score(y_test,grid.predict(combined_test)))
print(confusion_matrix(y_train,grid.predict(combined_train)))
print(confusion_matrix(y_test,grid.predict(combined_test)))
# Out:
# 0.9914163090128755
# 0.9032258064516129
# [[13599    12]
#  [    0   693]]
# [[3389   14]
#  [  19  154]]

# %%
clf=RandomForestClassifier(n_estimators=500,oob_score=True,n_jobs=-1,random_state=0)
clf.fit(text_train,y_train)
print(f1_score(y_train,clf.predict(text_train)))
print(f1_score(y_test,clf.predict(text_test)))
print(confusion_matrix(y_train,clf.predict(text_train)))
print(confusion_matrix(y_test,clf.predict(text_test)))
# Out:
# 1.0
# 0.8108108108108109
# [[13611     0]
#  [    0   693]]
# [[3400    3]
#  [  53  120]]

# %%
train_data = lgb.Dataset(combined_train, label=y_train)
test_data = lgb.Dataset(combined_test, label=y_test)

# %%
params = {}
params['learning_rate'] = 0.04
params['boosting_type'] = 'gbdt'
params['objective'] = 'binary'
params['max_depth'] = 5
params['lambda_l1'] = 0
params['lambda_l2'] = 0
params['n_jobs'] = 4
params['class_weight']='balanced'

clf = lgb.train( params,train_data, 1000, valid_sets=[test_data])
# Out:
# [1]	valid_0's binary_logloss: 0.175791
# [2]	valid_0's binary_logloss: 0.165258
# [3]	valid_0's binary_logloss: 0.156937
# [4]	valid_0's binary_logloss: 0.150762
# [5]	valid_0's binary_logloss: 0.145378
# [6]	valid_0's binary_logloss: 0.14056
# [7]	valid_0's binary_logloss: 0.136253
# [8]	valid_0's binary_logloss: 0.132348
# [9]	valid_0's binary_logloss: 0.129018
# [10]	valid_0's binary_logloss: 0.126437
# [11]	valid_0's binary_logloss: 0.123563
# [12]	valid_0's binary_logloss: 0.120702
# [13]	valid_0's binary_logloss: 0.118368
# [14]	valid_0's binary_logloss: 0.115976
# [15]	valid_0's binary_logloss: 0.113927
# [16]	valid_0's binary_logloss: 0.111226
# [17]	valid_0's binary_logloss: 0.109058
# [18]	valid_0's binary_logloss: 0.106666
# [19]	valid_0's binary_logloss: 0.104512
# [20]	valid_0's binary_logloss: 0.102335
# [21]	valid_0's binary_logloss: 0.100272
# [22]	valid_0's binary_logloss: 0.0986303
# [23]	valid_0's binary_logloss: 0.0970686
# [24]	valid_0's binary_logloss: 0.0954484
# [25]	valid_0's binary_logloss: 0.0939752
# [26]	valid_0's binary_logloss: 0.0928687
# [27]	valid_0's binary_logloss: 0.0914547
# [28]	valid_0's binary_logloss: 0.0898833
# [29]	valid_0's binary_logloss: 0.0887321
# [30]	valid_0's binary_logloss: 0.0877061
# [31]	valid_0's binary_logloss: 0.0867619
# [32]	valid_0's binary_logloss: 0.0858124
# [33]	valid_0's binary_logloss: 0.084665
# [34]	valid_0's binary_logloss: 0.0836472
# [35]	valid_0's binary_logloss: 0.0828294
# [36]	valid_0's binary_logloss: 0.081889
# [37]	valid_0's binary_logloss: 0.0810863
# [38]	valid_0's binary_logloss: 0.0799715
# [39]	valid_0's binary_logloss: 0.0794279
# [40]	valid_0's binary_logloss: 0.07874
# [41]	valid_0's binary_logloss: 0.0778064
# [42]	valid_0's binary_logloss: 0.0770959
# [43]	valid_0's binary_logloss: 0.0764539
# [44]	valid_0's binary_logloss: 0.0756786
# [45]	valid_0's binary_logloss: 0.074999
# [46]	valid_0's binary_logloss: 0.0744295
# [47]	valid_0's binary_logloss: 0.0739144
# [48]	valid_0's binary_logloss: 0.0733716
# [49]	valid_0's binary_logloss: 0.0727886
# [50]	valid_0's binary_logloss: 0.0723111
# [51]	valid_0's binary_logloss: 0.0717885
# [52]	valid_0's binary_logloss: 0.0712762
# [53]	valid_0's binary_logloss: 0.0709116
# [54]	valid_0's binary_logloss: 0.0704207
# [55]	valid_0's binary_logloss: 0.0699291
# [56]	valid_0's binary_logloss: 0.0694526
# [57]	valid_0's binary_logloss: 0.0687586
# [58]	valid_0's binary_logloss: 0.0681434
# [59]	valid_0's binary_logloss: 0.0677387
# [60]	valid_0's binary_logloss: 0.067307
# [61]	valid_0's binary_logloss: 0.0667188
# [62]	valid_0's binary_logloss: 0.066452
# [63]	valid_0's binary_logloss: 0.0661316
# [64]	valid_0's binary_logloss: 0.065746
# [65]	valid_0's binary_logloss: 0.0655151
# [66]	valid_0's binary_logloss: 0.0650701
# [67]	valid_0's binary_logloss: 0.0646689
# [68]	valid_0's binary_logloss: 0.0643768
# [69]	valid_0's binary_logloss: 0.0640277
# [70]	valid_0's binary_logloss: 0.0635138
# [71]	valid_0's binary_logloss: 0.063019
# [72]	valid_0's binary_logloss: 0.0627287
# [73]	valid_0's binary_logloss: 0.0624695
# [74]	valid_0's binary_logloss: 0.0622143
# [75]	valid_0's binary_logloss: 0.0618589
# [76]	valid_0's binary_logloss: 0.0616239
# [77]	valid_0's binary_logloss: 0.061303
# [78]	valid_0's binary_logloss: 0.0609685
# [79]	valid_0's binary_logloss: 0.0605403
# [80]	valid_0's binary_logloss: 0.0603276
# [81]	valid_0's binary_logloss: 0.0600444
# [82]	valid_0's binary_logloss: 0.0598666
# [83]	valid_0's binary_logloss: 0.0595912
# [84]	valid_0's binary_logloss: 0.0593938
# [85]	valid_0's binary_logloss: 0.0591067
# [86]	valid_0's binary_logloss: 0.0588841
# [87]	valid_0's binary_logloss: 0.0586903
# [88]	valid_0's binary_logloss: 0.0583972
# [89]	valid_0's binary_logloss: 0.0581856
# [90]	valid_0's binary_logloss: 0.0579842
# [91]	valid_0's binary_logloss: 0.0577449
# [92]	valid_0's binary_logloss: 0.0575735
# [93]	valid_0's binary_logloss: 0.0572731
# [94]	valid_0's binary_logloss: 0.0571184
# [95]	valid_0's binary_logloss: 0.0568598
# [96]	valid_0's binary_logloss: 0.0566713
# [97]	valid_0's binary_logloss: 0.0564751
# [98]	valid_0's binary_logloss: 0.0562717
# [99]	valid_0's binary_logloss: 0.0560644
# [100]	valid_0's binary_logloss: 0.0558815
# [101]	valid_0's binary_logloss: 0.0556573
# [102]	valid_0's binary_logloss: 0.0555257
# [103]	valid_0's binary_logloss: 0.0553358
# [104]	valid_0's binary_logloss: 0.0551956
# [105]	valid_0's binary_logloss: 0.0550197
# [106]	valid_0's binary_logloss: 0.0548852
# [107]	valid_0's binary_logloss: 0.0545998
# [108]	valid_0's binary_logloss: 0.0544078
# [109]	valid_0's binary_logloss: 0.0542055
# [110]	valid_0's binary_logloss: 0.0539874
# [111]	valid_0's binary_logloss: 0.0537739
# [112]	valid_0's binary_logloss: 0.0536192
# [113]	valid_0's binary_logloss: 0.0534744
# [114]	valid_0's binary_logloss: 0.0533169
# [115]	valid_0's binary_logloss: 0.0530597
# [116]	valid_0's binary_logloss: 0.0528962
# [117]	valid_0's binary_logloss: 0.0527157
# [118]	valid_0's binary_logloss: 0.0525331
# [119]	valid_0's binary_logloss: 0.0523941
# [120]	valid_0's binary_logloss: 0.0521541
# [121]	valid_0's binary_logloss: 0.0520936
# [122]	valid_0's binary_logloss: 0.0519923
# [123]	valid_0's binary_logloss: 0.0518913
# [124]	valid_0's binary_logloss: 0.0517294
# [125]	valid_0's binary_logloss: 0.0515835
# [126]	valid_0's binary_logloss: 0.0514713
# [127]	valid_0's binary_logloss: 0.0514409
# [128]	valid_0's binary_logloss: 0.05127
# [129]	valid_0's binary_logloss: 0.0511579
# [130]	valid_0's binary_logloss: 0.051094
# [131]	valid_0's binary_logloss: 0.0508996
# [132]	valid_0's binary_logloss: 0.0508099
# [133]	valid_0's binary_logloss: 0.0506856
# [134]	valid_0's binary_logloss: 0.0506151
# [135]	valid_0's binary_logloss: 0.0505075
# [136]	valid_0's binary_logloss: 0.0504348
# [137]	valid_0's binary_logloss: 0.0503044
# [138]	valid_0's binary_logloss: 0.0501889
# [139]	valid_0's binary_logloss: 0.05002
# [140]	valid_0's binary_logloss: 0.0499111
# [141]	valid_0's binary_logloss: 0.0497792
# [142]	valid_0's binary_logloss: 0.0496514
# [143]	valid_0's binary_logloss: 0.0495338
# [144]	valid_0's binary_logloss: 0.0494315
# [145]	valid_0's binary_logloss: 0.0493676
# [146]	valid_0's binary_logloss: 0.0492525
# [147]	valid_0's binary_logloss: 0.0492222
# [148]	valid_0's binary_logloss: 0.0491423
# [149]	valid_0's binary_logloss: 0.0490065
# [150]	valid_0's binary_logloss: 0.0488751
# [151]	valid_0's binary_logloss: 0.0487709
# [152]	valid_0's binary_logloss: 0.0486638
# [153]	valid_0's binary_logloss: 0.0485729
# [154]	valid_0's binary_logloss: 0.0484881
# [155]	valid_0's binary_logloss: 0.0483915
# [156]	valid_0's binary_logloss: 0.0483021
# [157]	valid_0's binary_logloss: 0.048136
# [158]	valid_0's binary_logloss: 0.048053
# [159]	valid_0's binary_logloss: 0.0479626
# [160]	valid_0's binary_logloss: 0.0479285
# [161]	valid_0's binary_logloss: 0.0478346
# [162]	valid_0's binary_logloss: 0.0477303
# [163]	valid_0's binary_logloss: 0.0475343
# [164]	valid_0's binary_logloss: 0.0473927
# [165]	valid_0's binary_logloss: 0.0473102
# [166]	valid_0's binary_logloss: 0.0472266
# [167]	valid_0's binary_logloss: 0.0471166
# [168]	valid_0's binary_logloss: 0.0470347
# [169]	valid_0's binary_logloss: 0.0469563
# [170]	valid_0's binary_logloss: 0.0469302
# [171]	valid_0's binary_logloss: 0.0468581
# [172]	valid_0's binary_logloss: 0.0467545
# [173]	valid_0's binary_logloss: 0.0466336
# [174]	valid_0's binary_logloss: 0.0465769
# [175]	valid_0's binary_logloss: 0.0465131
# [176]	valid_0's binary_logloss: 0.0464223
# [177]	valid_0's binary_logloss: 0.0463802
# [178]	valid_0's binary_logloss: 0.0463199
# [179]	valid_0's binary_logloss: 0.046259
# [180]	valid_0's binary_logloss: 0.0461665
# [181]	valid_0's binary_logloss: 0.0460631
# [182]	valid_0's binary_logloss: 0.046032
# [183]	valid_0's binary_logloss: 0.0459833
# [184]	valid_0's binary_logloss: 0.0458929
# [185]	valid_0's binary_logloss: 0.0458225
# [186]	valid_0's binary_logloss: 0.0457933
# [187]	valid_0's binary_logloss: 0.0456089
# [188]	valid_0's binary_logloss: 0.0455916
# [189]	valid_0's binary_logloss: 0.0455546
# [190]	valid_0's binary_logloss: 0.0454225
# [191]	valid_0's binary_logloss: 0.0454153
# [192]	valid_0's binary_logloss: 0.0453763
# [193]	valid_0's binary_logloss: 0.0452932
# [194]	valid_0's binary_logloss: 0.0452567
# [195]	valid_0's binary_logloss: 0.0451563
# [196]	valid_0's binary_logloss: 0.0450788
# [197]	valid_0's binary_logloss: 0.0449643
# [198]	valid_0's binary_logloss: 0.0448762
# [199]	valid_0's binary_logloss: 0.0448281
# [200]	valid_0's binary_logloss: 0.0447617
# [201]	valid_0's binary_logloss: 0.0447065
# [202]	valid_0's binary_logloss: 0.0446188
# [203]	valid_0's binary_logloss: 0.0445508
# [204]	valid_0's binary_logloss: 0.0444906
# [205]	valid_0's binary_logloss: 0.044455
# [206]	valid_0's binary_logloss: 0.0443981
# [207]	valid_0's binary_logloss: 0.0443247
# [208]	valid_0's binary_logloss: 0.0442528
# [209]	valid_0's binary_logloss: 0.0441825
# [210]	valid_0's binary_logloss: 0.0441658
# [211]	valid_0's binary_logloss: 0.0441055
# [212]	valid_0's binary_logloss: 0.0440091
# [213]	valid_0's binary_logloss: 0.0439255
# [214]	valid_0's binary_logloss: 0.0438289
# [215]	valid_0's binary_logloss: 0.0437844
# [216]	valid_0's binary_logloss: 0.0437386
# [217]	valid_0's binary_logloss: 0.0436746
# [218]	valid_0's binary_logloss: 0.0435718
# [219]	valid_0's binary_logloss: 0.0435235
# [220]	valid_0's binary_logloss: 0.0434613
# [221]	valid_0's binary_logloss: 0.0433954
# [222]	valid_0's binary_logloss: 0.043334
# [223]	valid_0's binary_logloss: 0.0432477
# [224]	valid_0's binary_logloss: 0.043228
# [225]	valid_0's binary_logloss: 0.0431712
# [226]	valid_0's binary_logloss: 0.0431033
# [227]	valid_0's binary_logloss: 0.0431006
# [228]	valid_0's binary_logloss: 0.0430633
# [229]	valid_0's binary_logloss: 0.0429623
# [230]	valid_0's binary_logloss: 0.0429482
# [231]	valid_0's binary_logloss: 0.0429231
# [232]	valid_0's binary_logloss: 0.0428202
# [233]	valid_0's binary_logloss: 0.0427916
# [234]	valid_0's binary_logloss: 0.0427592
# [235]	valid_0's binary_logloss: 0.0426937
# [236]	valid_0's binary_logloss: 0.0426453
# [237]	valid_0's binary_logloss: 0.0425931
# [238]	valid_0's binary_logloss: 0.0425618
# [239]	valid_0's binary_logloss: 0.0425447
# [240]	valid_0's binary_logloss: 0.0425075
# [241]	valid_0's binary_logloss: 0.0424669
# [242]	valid_0's binary_logloss: 0.0424183
# [243]	valid_0's binary_logloss: 0.0423941
# [244]	valid_0's binary_logloss: 0.0423808
# [245]	valid_0's binary_logloss: 0.0423318
# [246]	valid_0's binary_logloss: 0.0422811
# [247]	valid_0's binary_logloss: 0.0422359
# [248]	valid_0's binary_logloss: 0.042218
# [249]	valid_0's binary_logloss: 0.042184
# [250]	valid_0's binary_logloss: 0.0421619
# [251]	valid_0's binary_logloss: 0.0421072
# [252]	valid_0's binary_logloss: 0.0420481
# [253]	valid_0's binary_logloss: 0.0419379
# [254]	valid_0's binary_logloss: 0.0418793
# [255]	valid_0's binary_logloss: 0.0418328
# [256]	valid_0's binary_logloss: 0.0417591
# [257]	valid_0's binary_logloss: 0.0416922
# [258]	valid_0's binary_logloss: 0.0415918
# [259]	valid_0's binary_logloss: 0.0415481
# [260]	valid_0's binary_logloss: 0.0415142
# [261]	valid_0's binary_logloss: 0.0414765
# [262]	valid_0's binary_logloss: 0.0414373
# [263]	valid_0's binary_logloss: 0.0413799
# [264]	valid_0's binary_logloss: 0.0413368
# [265]	valid_0's binary_logloss: 0.0413204
# [266]	valid_0's binary_logloss: 0.0412606
# [267]	valid_0's binary_logloss: 0.0411867
# [268]	valid_0's binary_logloss: 0.0411462
# [269]	valid_0's binary_logloss: 0.0411259
# [270]	valid_0's binary_logloss: 0.0411253
# [271]	valid_0's binary_logloss: 0.0410507
# [272]	valid_0's binary_logloss: 0.0410546
# [273]	valid_0's binary_logloss: 0.0409771
# [274]	valid_0's binary_logloss: 0.0409467
# [275]	valid_0's binary_logloss: 0.0409199
# [276]	valid_0's binary_logloss: 0.040931
# [277]	valid_0's binary_logloss: 0.0409115
# [278]	valid_0's binary_logloss: 0.0409039
# [279]	valid_0's binary_logloss: 0.0408338
# [280]	valid_0's binary_logloss: 0.0408341
# [281]	valid_0's binary_logloss: 0.0407611
# [282]	valid_0's binary_logloss: 0.0406945
# [283]	valid_0's binary_logloss: 0.040643
# [284]	valid_0's binary_logloss: 0.0406186
# [285]	valid_0's binary_logloss: 0.0405877
# [286]	valid_0's binary_logloss: 0.040546
# [287]	valid_0's binary_logloss: 0.040504
# [288]	valid_0's binary_logloss: 0.0404746
# [289]	valid_0's binary_logloss: 0.0404129
# [290]	valid_0's binary_logloss: 0.0404161
# [291]	valid_0's binary_logloss: 0.0403796
# [292]	valid_0's binary_logloss: 0.0403044
# [293]	valid_0's binary_logloss: 0.0402439
# [294]	valid_0's binary_logloss: 0.040178
# [295]	valid_0's binary_logloss: 0.0401071
# [296]	valid_0's binary_logloss: 0.0400691
# [297]	valid_0's binary_logloss: 0.0400059
# [298]	valid_0's binary_logloss: 0.0399727
# [299]	valid_0's binary_logloss: 0.0399158
# [300]	valid_0's binary_logloss: 0.0398826
# [301]	valid_0's binary_logloss: 0.0398162
# [302]	valid_0's binary_logloss: 0.0398042
# [303]	valid_0's binary_logloss: 0.0397877
# [304]	valid_0's binary_logloss: 0.0397376
# [305]	valid_0's binary_logloss: 0.0397608
# [306]	valid_0's binary_logloss: 0.0397317
# [307]	valid_0's binary_logloss: 0.0396809
# [308]	valid_0's binary_logloss: 0.0396571
# [309]	valid_0's binary_logloss: 0.0396264
# [310]	valid_0's binary_logloss: 0.0396083
# [311]	valid_0's binary_logloss: 0.0395022
# [312]	valid_0's binary_logloss: 0.0394854
# [313]	valid_0's binary_logloss: 0.0394852
# [314]	valid_0's binary_logloss: 0.0394619
# [315]	valid_0's binary_logloss: 0.039428
# [316]	valid_0's binary_logloss: 0.0393571
# [317]	valid_0's binary_logloss: 0.03935
# [318]	valid_0's binary_logloss: 0.0393389
# [319]	valid_0's binary_logloss: 0.0392662
# [320]	valid_0's binary_logloss: 0.0392426
# [321]	valid_0's binary_logloss: 0.0392315
# [322]	valid_0's binary_logloss: 0.0391965
# [323]	valid_0's binary_logloss: 0.0391525
# [324]	valid_0's binary_logloss: 0.039106
# [325]	valid_0's binary_logloss: 0.0390816
# [326]	valid_0's binary_logloss: 0.0390369
# [327]	valid_0's binary_logloss: 0.0389988
# [328]	valid_0's binary_logloss: 0.0389435
# [329]	valid_0's binary_logloss: 0.0389186
# [330]	valid_0's binary_logloss: 0.0388898
# [331]	valid_0's binary_logloss: 0.0388706
# [332]	valid_0's binary_logloss: 0.0388492
# [333]	valid_0's binary_logloss: 0.038812
# [334]	valid_0's binary_logloss: 0.0388054
# [335]	valid_0's binary_logloss: 0.0387681
# [336]	valid_0's binary_logloss: 0.0387252
# [337]	valid_0's binary_logloss: 0.0386957
# [338]	valid_0's binary_logloss: 0.0386721
# [339]	valid_0's binary_logloss: 0.0386345
# [340]	valid_0's binary_logloss: 0.0386156
# [341]	valid_0's binary_logloss: 0.0385778
# [342]	valid_0's binary_logloss: 0.0385633
# [343]	valid_0's binary_logloss: 0.0385386
# [344]	valid_0's binary_logloss: 0.0385025
# [345]	valid_0's binary_logloss: 0.0384807
# [346]	valid_0's binary_logloss: 0.0384608
# [347]	valid_0's binary_logloss: 0.0384405
# [348]	valid_0's binary_logloss: 0.0384219
# [349]	valid_0's binary_logloss: 0.0384014
# [350]	valid_0's binary_logloss: 0.03836
# [351]	valid_0's binary_logloss: 0.0383496
# [352]	valid_0's binary_logloss: 0.0383571
# [353]	valid_0's binary_logloss: 0.0383501
# [354]	valid_0's binary_logloss: 0.0383472
# [355]	valid_0's binary_logloss: 0.0383233
# [356]	valid_0's binary_logloss: 0.0382897
# [357]	valid_0's binary_logloss: 0.0382233
# [358]	valid_0's binary_logloss: 0.0382209
# [359]	valid_0's binary_logloss: 0.0382235
# [360]	valid_0's binary_logloss: 0.0381595
# [361]	valid_0's binary_logloss: 0.0381166
# [362]	valid_0's binary_logloss: 0.0380988
# [363]	valid_0's binary_logloss: 0.0380866
# [364]	valid_0's binary_logloss: 0.0380972
# [365]	valid_0's binary_logloss: 0.0380874
# [366]	valid_0's binary_logloss: 0.0380788
# [367]	valid_0's binary_logloss: 0.0380748
# [368]	valid_0's binary_logloss: 0.0380536
# [369]	valid_0's binary_logloss: 0.0380327
# [370]	valid_0's binary_logloss: 0.0380227
# [371]	valid_0's binary_logloss: 0.0379475
# [372]	valid_0's binary_logloss: 0.037917
# [373]	valid_0's binary_logloss: 0.0378755
# [374]	valid_0's binary_logloss: 0.0378905
# [375]	valid_0's binary_logloss: 0.0378129
# [376]	valid_0's binary_logloss: 0.0377969
# [377]	valid_0's binary_logloss: 0.037784
# [378]	valid_0's binary_logloss: 0.037781
# [379]	valid_0's binary_logloss: 0.0377564
# [380]	valid_0's binary_logloss: 0.0377645
# [381]	valid_0's binary_logloss: 0.0377241
# [382]	valid_0's binary_logloss: 0.0376826
# [383]	valid_0's binary_logloss: 0.0376492
# [384]	valid_0's binary_logloss: 0.0376209
# [385]	valid_0's binary_logloss: 0.0375777
# [386]	valid_0's binary_logloss: 0.03756
# [387]	valid_0's binary_logloss: 0.0375336
# [388]	valid_0's binary_logloss: 0.0374817
# [389]	valid_0's binary_logloss: 0.0374862
# [390]	valid_0's binary_logloss: 0.0374741
# [391]	valid_0's binary_logloss: 0.037477
# [392]	valid_0's binary_logloss: 0.0374702
# [393]	valid_0's binary_logloss: 0.0374613
# [394]	valid_0's binary_logloss: 0.0374358
# [395]	valid_0's binary_logloss: 0.0373916
# [396]	valid_0's binary_logloss: 0.0373895
# [397]	valid_0's binary_logloss: 0.0373726
# [398]	valid_0's binary_logloss: 0.037328
# [399]	valid_0's binary_logloss: 0.037304
# [400]	valid_0's binary_logloss: 0.0372217
# [401]	valid_0's binary_logloss: 0.0371749
# [402]	valid_0's binary_logloss: 0.0371217
# [403]	valid_0's binary_logloss: 0.0371242
# [404]	valid_0's binary_logloss: 0.0371177
# [405]	valid_0's binary_logloss: 0.0371092
# [406]	valid_0's binary_logloss: 0.0371105
# [407]	valid_0's binary_logloss: 0.0370818
# [408]	valid_0's binary_logloss: 0.0370706
# [409]	valid_0's binary_logloss: 0.0370285
# [410]	valid_0's binary_logloss: 0.0370432
# [411]	valid_0's binary_logloss: 0.0370268
# [412]	valid_0's binary_logloss: 0.0370031
# [413]	valid_0's binary_logloss: 0.0370138
# [414]	valid_0's binary_logloss: 0.0370193
# [415]	valid_0's binary_logloss: 0.0369927
# [416]	valid_0's binary_logloss: 0.0369801
# [417]	valid_0's binary_logloss: 0.0369697
# [418]	valid_0's binary_logloss: 0.0369472
# [419]	valid_0's binary_logloss: 0.0369084
# [420]	valid_0's binary_logloss: 0.0369112
# [421]	valid_0's binary_logloss: 0.0369075
# [422]	valid_0's binary_logloss: 0.0368812
# [423]	valid_0's binary_logloss: 0.0368606
# [424]	valid_0's binary_logloss: 0.0368294
# [425]	valid_0's binary_logloss: 0.0367704
# [426]	valid_0's binary_logloss: 0.0367472
# [427]	valid_0's binary_logloss: 0.0367023
# [428]	valid_0's binary_logloss: 0.036658
# [429]	valid_0's binary_logloss: 0.0366152
# [430]	valid_0's binary_logloss: 0.0365898
# [431]	valid_0's binary_logloss: 0.0365908
# [432]	valid_0's binary_logloss: 0.0365989
# [433]	valid_0's binary_logloss: 0.0365607
# [434]	valid_0's binary_logloss: 0.0365447
# [435]	valid_0's binary_logloss: 0.0365487
# [436]	valid_0's binary_logloss: 0.0364977
# [437]	valid_0's binary_logloss: 0.0364648
# [438]	valid_0's binary_logloss: 0.0364423
# [439]	valid_0's binary_logloss: 0.0364234
# [440]	valid_0's binary_logloss: 0.0363844
# [441]	valid_0's binary_logloss: 0.0363665
# [442]	valid_0's binary_logloss: 0.0363666
# [443]	valid_0's binary_logloss: 0.0363756
# [444]	valid_0's binary_logloss: 0.036339
# [445]	valid_0's binary_logloss: 0.0363721
# [446]	valid_0's binary_logloss: 0.0363635
# [447]	valid_0's binary_logloss: 0.0363181
# [448]	valid_0's binary_logloss: 0.0363146
# [449]	valid_0's binary_logloss: 0.0363289
# [450]	valid_0's binary_logloss: 0.0363137
# [451]	valid_0's binary_logloss: 0.0363208
# [452]	valid_0's binary_logloss: 0.036295
# [453]	valid_0's binary_logloss: 0.0363024
# [454]	valid_0's binary_logloss: 0.0362741
# [455]	valid_0's binary_logloss: 0.036251
# [456]	valid_0's binary_logloss: 0.0362592
# [457]	valid_0's binary_logloss: 0.0362303
# [458]	valid_0's binary_logloss: 0.0362034
# [459]	valid_0's binary_logloss: 0.0361715
# [460]	valid_0's binary_logloss: 0.0361691
# [461]	valid_0's binary_logloss: 0.0361638
# [462]	valid_0's binary_logloss: 0.0361627
# [463]	valid_0's binary_logloss: 0.0361837
# [464]	valid_0's binary_logloss: 0.0361735
# [465]	valid_0's binary_logloss: 0.0361311
# [466]	valid_0's binary_logloss: 0.0361117
# [467]	valid_0's binary_logloss: 0.0360929
# [468]	valid_0's binary_logloss: 0.0360828
# [469]	valid_0's binary_logloss: 0.0360673
# [470]	valid_0's binary_logloss: 0.0360482
# [471]	valid_0's binary_logloss: 0.0360461
# [472]	valid_0's binary_logloss: 0.0360581
# [473]	valid_0's binary_logloss: 0.0360583
# [474]	valid_0's binary_logloss: 0.0360283
# [475]	valid_0's binary_logloss: 0.0360614
# [476]	valid_0's binary_logloss: 0.0360275
# [477]	valid_0's binary_logloss: 0.0360221
# [478]	valid_0's binary_logloss: 0.0360115
# [479]	valid_0's binary_logloss: 0.0359593
# [480]	valid_0's binary_logloss: 0.0359477
# [481]	valid_0's binary_logloss: 0.0359564
# [482]	valid_0's binary_logloss: 0.0359604
# [483]	valid_0's binary_logloss: 0.0359684
# [484]	valid_0's binary_logloss: 0.0359093
# [485]	valid_0's binary_logloss: 0.0359063
# [486]	valid_0's binary_logloss: 0.0358947
# [487]	valid_0's binary_logloss: 0.0358878
# [488]	valid_0's binary_logloss: 0.0358972
# [489]	valid_0's binary_logloss: 0.0358709
# [490]	valid_0's binary_logloss: 0.0358863
# [491]	valid_0's binary_logloss: 0.0358691
# [492]	valid_0's binary_logloss: 0.0358814
# [493]	valid_0's binary_logloss: 0.0359035
# [494]	valid_0's binary_logloss: 0.0358932
# [495]	valid_0's binary_logloss: 0.035909
# [496]	valid_0's binary_logloss: 0.0359063
# [497]	valid_0's binary_logloss: 0.0359083
# [498]	valid_0's binary_logloss: 0.0358967
# [499]	valid_0's binary_logloss: 0.0358906
# [500]	valid_0's binary_logloss: 0.0359267
# [501]	valid_0's binary_logloss: 0.0359389
# [502]	valid_0's binary_logloss: 0.0359375
# [503]	valid_0's binary_logloss: 0.0359567
# [504]	valid_0's binary_logloss: 0.0359786
# [505]	valid_0's binary_logloss: 0.0359884
# [506]	valid_0's binary_logloss: 0.035967
# [507]	valid_0's binary_logloss: 0.0359417
# [508]	valid_0's binary_logloss: 0.0359128
# [509]	valid_0's binary_logloss: 0.0359052
# [510]	valid_0's binary_logloss: 0.0359183
# [511]	valid_0's binary_logloss: 0.0358825
# [512]	valid_0's binary_logloss: 0.0358674
# [513]	valid_0's binary_logloss: 0.0358878
# [514]	valid_0's binary_logloss: 0.0358665
# [515]	valid_0's binary_logloss: 0.0358596
# [516]	valid_0's binary_logloss: 0.0358489
# [517]	valid_0's binary_logloss: 0.0358111
# [518]	valid_0's binary_logloss: 0.0358055
# [519]	valid_0's binary_logloss: 0.0358192
# [520]	valid_0's binary_logloss: 0.0357866
# [521]	valid_0's binary_logloss: 0.0357453
# [522]	valid_0's binary_logloss: 0.0357553
# [523]	valid_0's binary_logloss: 0.0357528
# [524]	valid_0's binary_logloss: 0.035738
# [525]	valid_0's binary_logloss: 0.0357114
# [526]	valid_0's binary_logloss: 0.0357151
# [527]	valid_0's binary_logloss: 0.0357002
# [528]	valid_0's binary_logloss: 0.0357103
# [529]	valid_0's binary_logloss: 0.0356785
# [530]	valid_0's binary_logloss: 0.0356452
# [531]	valid_0's binary_logloss: 0.0356201
# [532]	valid_0's binary_logloss: 0.0356297
# [533]	valid_0's binary_logloss: 0.0356419
# [534]	valid_0's binary_logloss: 0.0356452
# [535]	valid_0's binary_logloss: 0.0356064
# [536]	valid_0's binary_logloss: 0.0356286
# [537]	valid_0's binary_logloss: 0.0355903
# [538]	valid_0's binary_logloss: 0.0355891
# [539]	valid_0's binary_logloss: 0.0355919
# [540]	valid_0's binary_logloss: 0.0355871
# [541]	valid_0's binary_logloss: 0.0355536
# [542]	valid_0's binary_logloss: 0.035562
# [543]	valid_0's binary_logloss: 0.0355344
# [544]	valid_0's binary_logloss: 0.0355146
# [545]	valid_0's binary_logloss: 0.0355236
# [546]	valid_0's binary_logloss: 0.0354908
# [547]	valid_0's binary_logloss: 0.0354595
# [548]	valid_0's binary_logloss: 0.0354889
# [549]	valid_0's binary_logloss: 0.0354245
# [550]	valid_0's binary_logloss: 0.0354151
# [551]	valid_0's binary_logloss: 0.0354301
# [552]	valid_0's binary_logloss: 0.035442
# [553]	valid_0's binary_logloss: 0.0354445
# [554]	valid_0's binary_logloss: 0.0354384
# [555]	valid_0's binary_logloss: 0.0354213
# [556]	valid_0's binary_logloss: 0.0354179
# [557]	valid_0's binary_logloss: 0.0353984
# [558]	valid_0's binary_logloss: 0.0353921
# [559]	valid_0's binary_logloss: 0.035383
# [560]	valid_0's binary_logloss: 0.0353783
# [561]	valid_0's binary_logloss: 0.0353915
# [562]	valid_0's binary_logloss: 0.0353614
# [563]	valid_0's binary_logloss: 0.0353484
# [564]	valid_0's binary_logloss: 0.0353571
# [565]	valid_0's binary_logloss: 0.035366
# [566]	valid_0's binary_logloss: 0.0353671
# [567]	valid_0's binary_logloss: 0.0353472
# [568]	valid_0's binary_logloss: 0.0353508
# [569]	valid_0's binary_logloss: 0.0353331
# [570]	valid_0's binary_logloss: 0.0353108
# [571]	valid_0's binary_logloss: 0.035342
# [572]	valid_0's binary_logloss: 0.0353277
# [573]	valid_0's binary_logloss: 0.0353001
# [574]	valid_0's binary_logloss: 0.0352986
# [575]	valid_0's binary_logloss: 0.0353144
# [576]	valid_0's binary_logloss: 0.0353096
# [577]	valid_0's binary_logloss: 0.0352735
# [578]	valid_0's binary_logloss: 0.0352966
# [579]	valid_0's binary_logloss: 0.0352928
# [580]	valid_0's binary_logloss: 0.0352735
# [581]	valid_0's binary_logloss: 0.0352435
# [582]	valid_0's binary_logloss: 0.0352323
# [583]	valid_0's binary_logloss: 0.035254
# [584]	valid_0's binary_logloss: 0.0352553
# [585]	valid_0's binary_logloss: 0.0352751
# [586]	valid_0's binary_logloss: 0.0352453
# [587]	valid_0's binary_logloss: 0.0352406
# [588]	valid_0's binary_logloss: 0.0352263
# [589]	valid_0's binary_logloss: 0.0352059
# [590]	valid_0's binary_logloss: 0.0351904
# [591]	valid_0's binary_logloss: 0.0351948
# [592]	valid_0's binary_logloss: 0.0352184
# [593]	valid_0's binary_logloss: 0.0352124
# [594]	valid_0's binary_logloss: 0.0352049
# [595]	valid_0's binary_logloss: 0.0351954
# [596]	valid_0's binary_logloss: 0.0351839
# [597]	valid_0's binary_logloss: 0.0351638
# [598]	valid_0's binary_logloss: 0.0351539
# [599]	valid_0's binary_logloss: 0.0351491
# [600]	valid_0's binary_logloss: 0.0351424
# [601]	valid_0's binary_logloss: 0.0351362
# [602]	valid_0's binary_logloss: 0.035097
# [603]	valid_0's binary_logloss: 0.0351215
# [604]	valid_0's binary_logloss: 0.0351229
# [605]	valid_0's binary_logloss: 0.0351088
# [606]	valid_0's binary_logloss: 0.0351007
# [607]	valid_0's binary_logloss: 0.0351106
# [608]	valid_0's binary_logloss: 0.0351042
# [609]	valid_0's binary_logloss: 0.0350766
# [610]	valid_0's binary_logloss: 0.0350638
# [611]	valid_0's binary_logloss: 0.0350263
# [612]	valid_0's binary_logloss: 0.0350048
# [613]	valid_0's binary_logloss: 0.0349801
# [614]	valid_0's binary_logloss: 0.0349864
# [615]	valid_0's binary_logloss: 0.0349687
# [616]	valid_0's binary_logloss: 0.0349549
# [617]	valid_0's binary_logloss: 0.0349291
# [618]	valid_0's binary_logloss: 0.0349259
# [619]	valid_0's binary_logloss: 0.0349342
# [620]	valid_0's binary_logloss: 0.0349006
# [621]	valid_0's binary_logloss: 0.0348857
# [622]	valid_0's binary_logloss: 0.0348379
# [623]	valid_0's binary_logloss: 0.0348167
# [624]	valid_0's binary_logloss: 0.0348392
# [625]	valid_0's binary_logloss: 0.034836
# [626]	valid_0's binary_logloss: 0.0348003
# [627]	valid_0's binary_logloss: 0.0348156
# [628]	valid_0's binary_logloss: 0.0347873
# [629]	valid_0's binary_logloss: 0.0348076
# [630]	valid_0's binary_logloss: 0.0348063
# [631]	valid_0's binary_logloss: 0.034775
# [632]	valid_0's binary_logloss: 0.0347721
# [633]	valid_0's binary_logloss: 0.0347763
# [634]	valid_0's binary_logloss: 0.0347419
# [635]	valid_0's binary_logloss: 0.0347542
# [636]	valid_0's binary_logloss: 0.0347407
# [637]	valid_0's binary_logloss: 0.0347528
# [638]	valid_0's binary_logloss: 0.0347738
# [639]	valid_0's binary_logloss: 0.03477
# [640]	valid_0's binary_logloss: 0.0347666
# [641]	valid_0's binary_logloss: 0.0347417
# [642]	valid_0's binary_logloss: 0.0347291
# [643]	valid_0's binary_logloss: 0.0347212
# [644]	valid_0's binary_logloss: 0.0347146
# [645]	valid_0's binary_logloss: 0.0346966
# [646]	valid_0's binary_logloss: 0.0346779
# [647]	valid_0's binary_logloss: 0.0346959
# [648]	valid_0's binary_logloss: 0.0346961
# [649]	valid_0's binary_logloss: 0.034685
# [650]	valid_0's binary_logloss: 0.0346582
# [651]	valid_0's binary_logloss: 0.0346616
# [652]	valid_0's binary_logloss: 0.0346825
# [653]	valid_0's binary_logloss: 0.0346568
# [654]	valid_0's binary_logloss: 0.034621
# [655]	valid_0's binary_logloss: 0.0346424
# [656]	valid_0's binary_logloss: 0.0346432
# [657]	valid_0's binary_logloss: 0.0346415
# [658]	valid_0's binary_logloss: 0.0346341
# [659]	valid_0's binary_logloss: 0.034636
# [660]	valid_0's binary_logloss: 0.0346449
# [661]	valid_0's binary_logloss: 0.0346163
# [662]	valid_0's binary_logloss: 0.0346291
# [663]	valid_0's binary_logloss: 0.0346035
# [664]	valid_0's binary_logloss: 0.0346058
# [665]	valid_0's binary_logloss: 0.0346238
# [666]	valid_0's binary_logloss: 0.0346072
# [667]	valid_0's binary_logloss: 0.0346027
# [668]	valid_0's binary_logloss: 0.0345762
# [669]	valid_0's binary_logloss: 0.0345722
# [670]	valid_0's binary_logloss: 0.0345679
# [671]	valid_0's binary_logloss: 0.0345798
# [672]	valid_0's binary_logloss: 0.0345904
# [673]	valid_0's binary_logloss: 0.0345573
# [674]	valid_0's binary_logloss: 0.0345319
# [675]	valid_0's binary_logloss: 0.0345699
# [676]	valid_0's binary_logloss: 0.0345423
# [677]	valid_0's binary_logloss: 0.0345583
# [678]	valid_0's binary_logloss: 0.0345386
# [679]	valid_0's binary_logloss: 0.0345268
# [680]	valid_0's binary_logloss: 0.0345356
# [681]	valid_0's binary_logloss: 0.0344973
# [682]	valid_0's binary_logloss: 0.0344944
# [683]	valid_0's binary_logloss: 0.0345001
# [684]	valid_0's binary_logloss: 0.0345138
# [685]	valid_0's binary_logloss: 0.0345246
# [686]	valid_0's binary_logloss: 0.0345344
# [687]	valid_0's binary_logloss: 0.0345078
# [688]	valid_0's binary_logloss: 0.0344983
# [689]	valid_0's binary_logloss: 0.0345026
# [690]	valid_0's binary_logloss: 0.0344773
# [691]	valid_0's binary_logloss: 0.0344367
# [692]	valid_0's binary_logloss: 0.0344444
# [693]	valid_0's binary_logloss: 0.0344357
# [694]	valid_0's binary_logloss: 0.0344254
# [695]	valid_0's binary_logloss: 0.0344281
# [696]	valid_0's binary_logloss: 0.0344206
# [697]	valid_0's binary_logloss: 0.0344372
# [698]	valid_0's binary_logloss: 0.0344188
# [699]	valid_0's binary_logloss: 0.0343986
# [700]	valid_0's binary_logloss: 0.0344261
# [701]	valid_0's binary_logloss: 0.0344291
# [702]	valid_0's binary_logloss: 0.0345035
# [703]	valid_0's binary_logloss: 0.0345065
# [704]	valid_0's binary_logloss: 0.0345323
# [705]	valid_0's binary_logloss: 0.0345587
# [706]	valid_0's binary_logloss: 0.0345557
# [707]	valid_0's binary_logloss: 0.0345618
# [708]	valid_0's binary_logloss: 0.0345415
# [709]	valid_0's binary_logloss: 0.0345741
# [710]	valid_0's binary_logloss: 0.034533
# [711]	valid_0's binary_logloss: 0.0345178
# [712]	valid_0's binary_logloss: 0.034504
# [713]	valid_0's binary_logloss: 0.0345015
# [714]	valid_0's binary_logloss: 0.0345092
# [715]	valid_0's binary_logloss: 0.034484
# [716]	valid_0's binary_logloss: 0.0344687
# [717]	valid_0's binary_logloss: 0.0344563
# [718]	valid_0's binary_logloss: 0.0344493
# [719]	valid_0's binary_logloss: 0.0344407
# [720]	valid_0's binary_logloss: 0.0344173
# [721]	valid_0's binary_logloss: 0.0344298
# [722]	valid_0's binary_logloss: 0.0344274
# [723]	valid_0's binary_logloss: 0.0344331
# [724]	valid_0's binary_logloss: 0.0343951
# [725]	valid_0's binary_logloss: 0.0343872
# [726]	valid_0's binary_logloss: 0.0343823
# [727]	valid_0's binary_logloss: 0.03438
# [728]	valid_0's binary_logloss: 0.034374
# [729]	valid_0's binary_logloss: 0.0343839
# [730]	valid_0's binary_logloss: 0.0343878
# [731]	valid_0's binary_logloss: 0.0343727
# [732]	valid_0's binary_logloss: 0.0343801
# [733]	valid_0's binary_logloss: 0.0343722
# [734]	valid_0's binary_logloss: 0.0343595
# [735]	valid_0's binary_logloss: 0.0343551
# [736]	valid_0's binary_logloss: 0.0343346
# [737]	valid_0's binary_logloss: 0.0343199
# [738]	valid_0's binary_logloss: 0.034342
# [739]	valid_0's binary_logloss: 0.0343675
# [740]	valid_0's binary_logloss: 0.034351
# [741]	valid_0's binary_logloss: 0.0343509
# [742]	valid_0's binary_logloss: 0.0343455
# [743]	valid_0's binary_logloss: 0.0343511
# [744]	valid_0's binary_logloss: 0.0343759
# [745]	valid_0's binary_logloss: 0.0343644
# [746]	valid_0's binary_logloss: 0.0343529
# [747]	valid_0's binary_logloss: 0.0343416
# [748]	valid_0's binary_logloss: 0.0342863
# [749]	valid_0's binary_logloss: 0.0342724
# [750]	valid_0's binary_logloss: 0.0342494
# [751]	valid_0's binary_logloss: 0.034274
# [752]	valid_0's binary_logloss: 0.034269
# [753]	valid_0's binary_logloss: 0.0342588
# [754]	valid_0's binary_logloss: 0.0342601
# [755]	valid_0's binary_logloss: 0.0342408
# [756]	valid_0's binary_logloss: 0.0342227
# [757]	valid_0's binary_logloss: 0.034246
# [758]	valid_0's binary_logloss: 0.0342332
# [759]	valid_0's binary_logloss: 0.0342404
# [760]	valid_0's binary_logloss: 0.0342183
# [761]	valid_0's binary_logloss: 0.0342001
# [762]	valid_0's binary_logloss: 0.0341961
# [763]	valid_0's binary_logloss: 0.0341896
# [764]	valid_0's binary_logloss: 0.0341827
# [765]	valid_0's binary_logloss: 0.034174
# [766]	valid_0's binary_logloss: 0.0341645
# [767]	valid_0's binary_logloss: 0.0341555
# [768]	valid_0's binary_logloss: 0.0341782
# [769]	valid_0's binary_logloss: 0.0341991
# [770]	valid_0's binary_logloss: 0.0341774
# [771]	valid_0's binary_logloss: 0.0341771
# [772]	valid_0's binary_logloss: 0.0341771
# [773]	valid_0's binary_logloss: 0.0341747
# [774]	valid_0's binary_logloss: 0.0341715
# [775]	valid_0's binary_logloss: 0.0341859
# [776]	valid_0's binary_logloss: 0.0341815
# [777]	valid_0's binary_logloss: 0.0342033
# [778]	valid_0's binary_logloss: 0.0342165
# [779]	valid_0's binary_logloss: 0.0341797
# [780]	valid_0's binary_logloss: 0.0342086
# [781]	valid_0's binary_logloss: 0.034211
# [782]	valid_0's binary_logloss: 0.034185
# [783]	valid_0's binary_logloss: 0.0342144
# [784]	valid_0's binary_logloss: 0.0342065
# [785]	valid_0's binary_logloss: 0.0342087
# [786]	valid_0's binary_logloss: 0.0342149
# [787]	valid_0's binary_logloss: 0.0342209
# [788]	valid_0's binary_logloss: 0.0342454
# [789]	valid_0's binary_logloss: 0.0342296
# [790]	valid_0's binary_logloss: 0.0342068
# [791]	valid_0's binary_logloss: 0.0342406
# [792]	valid_0's binary_logloss: 0.0342275
# [793]	valid_0's binary_logloss: 0.0342296
# [794]	valid_0's binary_logloss: 0.0342621
# [795]	valid_0's binary_logloss: 0.0342495
# [796]	valid_0's binary_logloss: 0.0342309
# [797]	valid_0's binary_logloss: 0.0341952
# [798]	valid_0's binary_logloss: 0.0342221
# [799]	valid_0's binary_logloss: 0.0342266
# [800]	valid_0's binary_logloss: 0.0342264
# [801]	valid_0's binary_logloss: 0.0342532
# [802]	valid_0's binary_logloss: 0.0342332
# [803]	valid_0's binary_logloss: 0.034212
# [804]	valid_0's binary_logloss: 0.0342274
# [805]	valid_0's binary_logloss: 0.0342288
# [806]	valid_0's binary_logloss: 0.0342436
# [807]	valid_0's binary_logloss: 0.0342385
# [808]	valid_0's binary_logloss: 0.0342541
# [809]	valid_0's binary_logloss: 0.0342105
# [810]	valid_0's binary_logloss: 0.0342214
# [811]	valid_0's binary_logloss: 0.0342097
# [812]	valid_0's binary_logloss: 0.0342178
# [813]	valid_0's binary_logloss: 0.034214
# [814]	valid_0's binary_logloss: 0.034217
# [815]	valid_0's binary_logloss: 0.0342247
# [816]	valid_0's binary_logloss: 0.0342009
# [817]	valid_0's binary_logloss: 0.0342033
# [818]	valid_0's binary_logloss: 0.0342123
# [819]	valid_0's binary_logloss: 0.0342016
# [820]	valid_0's binary_logloss: 0.034224
# [821]	valid_0's binary_logloss: 0.034213
# [822]	valid_0's binary_logloss: 0.0342299
# [823]	valid_0's binary_logloss: 0.0342316
# [824]	valid_0's binary_logloss: 0.0342146
# [825]	valid_0's binary_logloss: 0.0342048
# [826]	valid_0's binary_logloss: 0.0342263
# [827]	valid_0's binary_logloss: 0.0342298
# [828]	valid_0's binary_logloss: 0.0342171
# [829]	valid_0's binary_logloss: 0.0342468
# [830]	valid_0's binary_logloss: 0.0342743
# [831]	valid_0's binary_logloss: 0.0342912
# [832]	valid_0's binary_logloss: 0.0343433
# [833]	valid_0's binary_logloss: 0.0343606
# [834]	valid_0's binary_logloss: 0.0343799
# [835]	valid_0's binary_logloss: 0.0343952
# [836]	valid_0's binary_logloss: 0.0343956
# [837]	valid_0's binary_logloss: 0.0344056
# [838]	valid_0's binary_logloss: 0.034453
# [839]	valid_0's binary_logloss: 0.0344509
# [840]	valid_0's binary_logloss: 0.0344758
# [841]	valid_0's binary_logloss: 0.0344772
# [842]	valid_0's binary_logloss: 0.0344495
# [843]	valid_0's binary_logloss: 0.0344439
# [844]	valid_0's binary_logloss: 0.0344276
# [845]	valid_0's binary_logloss: 0.0344273
# [846]	valid_0's binary_logloss: 0.0344495
# [847]	valid_0's binary_logloss: 0.0344307
# [848]	valid_0's binary_logloss: 0.0344215
# [849]	valid_0's binary_logloss: 0.0344515
# [850]	valid_0's binary_logloss: 0.0344384
# [851]	valid_0's binary_logloss: 0.0344484
# [852]	valid_0's binary_logloss: 0.0344387
# [853]	valid_0's binary_logloss: 0.0344624
# [854]	valid_0's binary_logloss: 0.0344518
# [855]	valid_0's binary_logloss: 0.034467
# [856]	valid_0's binary_logloss: 0.0344995
# [857]	valid_0's binary_logloss: 0.0345069
# [858]	valid_0's binary_logloss: 0.0345244
# [859]	valid_0's binary_logloss: 0.0345189
# [860]	valid_0's binary_logloss: 0.0344954
# [861]	valid_0's binary_logloss: 0.0345141
# [862]	valid_0's binary_logloss: 0.0345233
# [863]	valid_0's binary_logloss: 0.0345486
# [864]	valid_0's binary_logloss: 0.034532
# [865]	valid_0's binary_logloss: 0.0345027
# [866]	valid_0's binary_logloss: 0.0345098
# [867]	valid_0's binary_logloss: 0.0344787
# [868]	valid_0's binary_logloss: 0.0344725
# [869]	valid_0's binary_logloss: 0.034475
# [870]	valid_0's binary_logloss: 0.0344715
# [871]	valid_0's binary_logloss: 0.0344944
# [872]	valid_0's binary_logloss: 0.0345219
# [873]	valid_0's binary_logloss: 0.0345208
# [874]	valid_0's binary_logloss: 0.0345354
# [875]	valid_0's binary_logloss: 0.0345467
# [876]	valid_0's binary_logloss: 0.0345508
# [877]	valid_0's binary_logloss: 0.0345544
# [878]	valid_0's binary_logloss: 0.0345325
# [879]	valid_0's binary_logloss: 0.0345346
# [880]	valid_0's binary_logloss: 0.0345569
# [881]	valid_0's binary_logloss: 0.0345709
# [882]	valid_0's binary_logloss: 0.0345636
# [883]	valid_0's binary_logloss: 0.0345841
# [884]	valid_0's binary_logloss: 0.0345676
# [885]	valid_0's binary_logloss: 0.0345632
# [886]	valid_0's binary_logloss: 0.0345487
# [887]	valid_0's binary_logloss: 0.0345515
# [888]	valid_0's binary_logloss: 0.0345305
# [889]	valid_0's binary_logloss: 0.0345286
# [890]	valid_0's binary_logloss: 0.0345508
# [891]	valid_0's binary_logloss: 0.0345403
# [892]	valid_0's binary_logloss: 0.034579
# [893]	valid_0's binary_logloss: 0.0346344
# [894]	valid_0's binary_logloss: 0.0346401
# [895]	valid_0's binary_logloss: 0.0346177
# [896]	valid_0's binary_logloss: 0.0346101
# [897]	valid_0's binary_logloss: 0.0346409
# [898]	valid_0's binary_logloss: 0.0346321
# [899]	valid_0's binary_logloss: 0.0346397
# [900]	valid_0's binary_logloss: 0.0346366
# [901]	valid_0's binary_logloss: 0.0346327
# [902]	valid_0's binary_logloss: 0.0346174
# [903]	valid_0's binary_logloss: 0.0345863
# [904]	valid_0's binary_logloss: 0.0346313
# [905]	valid_0's binary_logloss: 0.034679
# [906]	valid_0's binary_logloss: 0.0346818
# [907]	valid_0's binary_logloss: 0.0346555
# [908]	valid_0's binary_logloss: 0.0346558
# [909]	valid_0's binary_logloss: 0.0346594
# [910]	valid_0's binary_logloss: 0.0346531
# [911]	valid_0's binary_logloss: 0.034689
# [912]	valid_0's binary_logloss: 0.0346974
# [913]	valid_0's binary_logloss: 0.0347147
# [914]	valid_0's binary_logloss: 0.0347492
# [915]	valid_0's binary_logloss: 0.0347422
# [916]	valid_0's binary_logloss: 0.0347331
# [917]	valid_0's binary_logloss: 0.0347286
# [918]	valid_0's binary_logloss: 0.0347181
# [919]	valid_0's binary_logloss: 0.0347205
# [920]	valid_0's binary_logloss: 0.0347285
# [921]	valid_0's binary_logloss: 0.0347132
# [922]	valid_0's binary_logloss: 0.0347024
# [923]	valid_0's binary_logloss: 0.0347029
# [924]	valid_0's binary_logloss: 0.0347249
# [925]	valid_0's binary_logloss: 0.0347601
# [926]	valid_0's binary_logloss: 0.0347636
# [927]	valid_0's binary_logloss: 0.0347621
# [928]	valid_0's binary_logloss: 0.0347474
# [929]	valid_0's binary_logloss: 0.0347555
# [930]	valid_0's binary_logloss: 0.0347682
# [931]	valid_0's binary_logloss: 0.0347691
# [932]	valid_0's binary_logloss: 0.0347546
# [933]	valid_0's binary_logloss: 0.0347506
# [934]	valid_0's binary_logloss: 0.0347716
# [935]	valid_0's binary_logloss: 0.0347647
# [936]	valid_0's binary_logloss: 0.0347951
# [937]	valid_0's binary_logloss: 0.0348094
# [938]	valid_0's binary_logloss: 0.0348163
# [939]	valid_0's binary_logloss: 0.0348169
# [940]	valid_0's binary_logloss: 0.0348167
# [941]	valid_0's binary_logloss: 0.0348121
# [942]	valid_0's binary_logloss: 0.0348502
# [943]	valid_0's binary_logloss: 0.0348524
# [944]	valid_0's binary_logloss: 0.034847
# [945]	valid_0's binary_logloss: 0.0348287
# [946]	valid_0's binary_logloss: 0.0348151
# [947]	valid_0's binary_logloss: 0.034818
# [948]	valid_0's binary_logloss: 0.034815
# [949]	valid_0's binary_logloss: 0.0347977
# [950]	valid_0's binary_logloss: 0.0348078
# [951]	valid_0's binary_logloss: 0.0348262
# [952]	valid_0's binary_logloss: 0.0348475
# [953]	valid_0's binary_logloss: 0.0348465
# [954]	valid_0's binary_logloss: 0.0348634
# [955]	valid_0's binary_logloss: 0.0348767
# [956]	valid_0's binary_logloss: 0.0349024
# [957]	valid_0's binary_logloss: 0.0348968
# [958]	valid_0's binary_logloss: 0.0348899
# [959]	valid_0's binary_logloss: 0.0349007
# [960]	valid_0's binary_logloss: 0.0349209
# [961]	valid_0's binary_logloss: 0.0349355
# [962]	valid_0's binary_logloss: 0.034957
# [963]	valid_0's binary_logloss: 0.034951
# [964]	valid_0's binary_logloss: 0.0349822
# [965]	valid_0's binary_logloss: 0.0349558
# [966]	valid_0's binary_logloss: 0.0349509
# [967]	valid_0's binary_logloss: 0.0349047
# [968]	valid_0's binary_logloss: 0.0349266
# [969]	valid_0's binary_logloss: 0.0349378
# [970]	valid_0's binary_logloss: 0.0349462
# [971]	valid_0's binary_logloss: 0.0349361
# [972]	valid_0's binary_logloss: 0.0349306
# [973]	valid_0's binary_logloss: 0.0349577
# [974]	valid_0's binary_logloss: 0.0349947
# [975]	valid_0's binary_logloss: 0.0350139
# [976]	valid_0's binary_logloss: 0.0349979
# [977]	valid_0's binary_logloss: 0.0349873
# [978]	valid_0's binary_logloss: 0.0349644
# [979]	valid_0's binary_logloss: 0.0349779
# [980]	valid_0's binary_logloss: 0.0350109
# [981]	valid_0's binary_logloss: 0.0350323
# [982]	valid_0's binary_logloss: 0.0350437
# [983]	valid_0's binary_logloss: 0.0350395
# [984]	valid_0's binary_logloss: 0.0350809
# [985]	valid_0's binary_logloss: 0.035105
# [986]	valid_0's binary_logloss: 0.0351413
# [987]	valid_0's binary_logloss: 0.0351874
# [988]	valid_0's binary_logloss: 0.0351802
# [989]	valid_0's binary_logloss: 0.0351757
# [990]	valid_0's binary_logloss: 0.0351772
# [991]	valid_0's binary_logloss: 0.0351624
# [992]	valid_0's binary_logloss: 0.0351807
# [993]	valid_0's binary_logloss: 0.0351666
# [994]	valid_0's binary_logloss: 0.0351876
# [995]	valid_0's binary_logloss: 0.0352154
# [996]	valid_0's binary_logloss: 0.0352142
# [997]	valid_0's binary_logloss: 0.0351983
# [998]	valid_0's binary_logloss: 0.035211
# [999]	valid_0's binary_logloss: 0.0351928
# [1000]	valid_0's binary_logloss: 0.035198

# %%
thresh=0.20
print(f1_score(y_train,list(map(lambda x:1 if x>thresh else 0,clf.predict(combined_train)))))
print(f1_score(y_test,list(map(lambda x:1 if x>thresh else 0,clf.predict(combined_test)))))
print(confusion_matrix(y_train,list(map(lambda x:1 if x>thresh else 0,clf.predict(combined_train)))))
print(confusion_matrix(y_test,list(map(lambda x:1 if x>thresh else 0,clf.predict(combined_test)))))
# Out:
# /usr/local/lib/python3.6/dist-packages/lightgbm/basic.py:478: UserWarning:
#
# Converting data to scipy sparse matrix.
# 1.0
# 0.9129129129129129
# [[13611     0]
#  [    0   693]]
# [[3395    8]
#  [  21  152]]
